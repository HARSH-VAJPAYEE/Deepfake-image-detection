# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/train'
validation_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 175
IMG_HEIGHT = 175
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.1,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 2634 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : fake
# 1 : real

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2L Model**
#
#
# ### i. Create a EfficientNetV2L Model

# %%
base_model = tf.keras.applications.EfficientNetV2L(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(175,175,3),
                     include_preprocessing=True

                     )

base_model.trainable=True

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-l (Functiona  (None, 6, 6, 1280)       117746848
#  l)
#
#  batch_normalization (BatchN  (None, 6, 6, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 118,576,162
# Trainable params: 118,057,186
# Non-trainable params: 518,976
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
early = tf.keras.callbacks.EarlyStopping( patience=10,
                                          min_delta=0.001,
                                          restore_best_weights=True)

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.8/dist-packages (0.19.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)
sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=25,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=75,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/75
# 25/25 - 363s - loss: 0.7088 - accuracy: 0.5562 - precision: 0.5562 - recall: 0.5562 - auc: 0.5486 - f1_Score: 0.5159 - val_loss: 0.6950 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.4531 - val_f1_Score: 0.3118 - lr: 0.0010 - 363s/epoch - 15s/step
# Epoch 2/75
# 25/25 - 225s - loss: 0.7036 - accuracy: 0.5300 - precision: 0.5300 - recall: 0.5300 - auc: 0.5519 - f1_Score: 0.4800 - val_loss: 0.7041 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4637 - val_f1_Score: 0.3263 - lr: 0.0010 - 225s/epoch - 9s/step
# Epoch 3/75
# 25/25 - 175s - loss: 0.6894 - accuracy: 0.5500 - precision: 0.5500 - recall: 0.5500 - auc: 0.5752 - f1_Score: 0.4922 - val_loss: 0.6764 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6383 - val_f1_Score: 0.6085 - lr: 0.0010 - 175s/epoch - 7s/step
# Epoch 4/75
# 25/25 - 127s - loss: 0.6938 - accuracy: 0.5425 - precision: 0.5425 - recall: 0.5425 - auc: 0.5582 - f1_Score: 0.4786 - val_loss: 0.6803 - val_accuracy: 0.5781 - val_precision: 0.5781 - val_recall: 0.5781 - val_auc: 0.5757 - val_f1_Score: 0.3663 - lr: 0.0010 - 127s/epoch - 5s/step
# Epoch 5/75
# 25/25 - 108s - loss: 0.6946 - accuracy: 0.5334 - precision: 0.5334 - recall: 0.5334 - auc: 0.5316 - f1_Score: 0.4272 - val_loss: 0.7122 - val_accuracy: 0.4219 - val_precision: 0.4219 - val_recall: 0.4219 - val_auc: 0.3811 - val_f1_Score: 0.2967 - lr: 0.0010 - 108s/epoch - 4s/step
# Epoch 6/75
# 25/25 - 91s - loss: 0.6914 - accuracy: 0.5562 - precision: 0.5562 - recall: 0.5562 - auc: 0.5529 - f1_Score: 0.4505 - val_loss: 0.6855 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.5630 - val_f1_Score: 0.5516 - lr: 0.0010 - 91s/epoch - 4s/step
# Epoch 7/75
# 25/25 - 79s - loss: 0.6898 - accuracy: 0.5437 - precision: 0.5437 - recall: 0.5437 - auc: 0.5553 - f1_Score: 0.5007 - val_loss: 0.7083 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.4778 - val_f1_Score: 0.3118 - lr: 0.0010 - 79s/epoch - 3s/step
# Epoch 8/75
# 25/25 - 64s - loss: 0.6848 - accuracy: 0.5688 - precision: 0.5688 - recall: 0.5688 - auc: 0.5962 - f1_Score: 0.5317 - val_loss: 0.7051 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5269 - val_f1_Score: 0.5238 - lr: 0.0010 - 64s/epoch - 3s/step
# Epoch 9/75
# 25/25 - 60s - loss: 0.6974 - accuracy: 0.5362 - precision: 0.5362 - recall: 0.5362 - auc: 0.5447 - f1_Score: 0.5094 - val_loss: 0.7033 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.4673 - val_f1_Score: 0.3720 - lr: 3.1623e-04 - 60s/epoch - 2s/step
# Epoch 10/75
# 25/25 - 54s - loss: 0.6886 - accuracy: 0.5225 - precision: 0.5225 - recall: 0.5225 - auc: 0.5446 - f1_Score: 0.5021 - val_loss: 0.6749 - val_accuracy: 0.5781 - val_precision: 0.5781 - val_recall: 0.5781 - val_auc: 0.6017 - val_f1_Score: 0.5022 - lr: 3.1623e-04 - 54s/epoch - 2s/step
# Epoch 11/75
# 25/25 - 46s - loss: 0.6722 - accuracy: 0.5650 - precision: 0.5650 - recall: 0.5650 - auc: 0.6153 - f1_Score: 0.5335 - val_loss: 0.6914 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5105 - val_f1_Score: 0.4842 - lr: 3.1623e-04 - 46s/epoch - 2s/step
# Epoch 12/75
# 25/25 - 48s - loss: 0.6745 - accuracy: 0.5688 - precision: 0.5688 - recall: 0.5688 - auc: 0.6025 - f1_Score: 0.5636 - val_loss: 0.6653 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6123 - val_f1_Score: 0.6070 - lr: 3.1623e-04 - 48s/epoch - 2s/step
# Epoch 13/75
# 25/25 - 50s - loss: 0.6653 - accuracy: 0.5900 - precision: 0.5900 - recall: 0.5900 - auc: 0.6356 - f1_Score: 0.5802 - val_loss: 0.6040 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.7440 - val_f1_Score: 0.6769 - lr: 3.1623e-04 - 50s/epoch - 2s/step
# Epoch 14/75
# 25/25 - 46s - loss: 0.6430 - accuracy: 0.6325 - precision: 0.6325 - recall: 0.6325 - auc: 0.6798 - f1_Score: 0.6232 - val_loss: 0.7271 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5356 - val_f1_Score: 0.4113 - lr: 3.1623e-04 - 46s/epoch - 2s/step
# Epoch 15/75
# 25/25 - 47s - loss: 0.6774 - accuracy: 0.5797 - precision: 0.5797 - recall: 0.5797 - auc: 0.6115 - f1_Score: 0.5646 - val_loss: 0.7742 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5391 - val_f1_Score: 0.3402 - lr: 3.1623e-04 - 47s/epoch - 2s/step
# Epoch 16/75
# 25/25 - 41s - loss: 0.6715 - accuracy: 0.6200 - precision: 0.6200 - recall: 0.6200 - auc: 0.6369 - f1_Score: 0.5851 - val_loss: 0.7738 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4292 - val_f1_Score: 0.3043 - lr: 3.1623e-04 - 41s/epoch - 2s/step
# Epoch 17/75
# 25/25 - 40s - loss: 0.6638 - accuracy: 0.6062 - precision: 0.6062 - recall: 0.6062 - auc: 0.6398 - f1_Score: 0.5768 - val_loss: 0.6621 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6357 - val_f1_Score: 0.4679 - lr: 3.1623e-04 - 40s/epoch - 2s/step
# Epoch 18/75
# 25/25 - 44s - loss: 0.6257 - accuracy: 0.6687 - precision: 0.6687 - recall: 0.6687 - auc: 0.7083 - f1_Score: 0.6575 - val_loss: 0.6197 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7091 - val_f1_Score: 0.5883 - lr: 3.1623e-04 - 44s/epoch - 2s/step
# Epoch 19/75
# 25/25 - 44s - loss: 0.6195 - accuracy: 0.6712 - precision: 0.6712 - recall: 0.6712 - auc: 0.7208 - f1_Score: 0.6527 - val_loss: 0.5848 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7678 - val_f1_Score: 0.6333 - lr: 1.0000e-04 - 44s/epoch - 2s/step
# Epoch 20/75
# 25/25 - 38s - loss: 0.5521 - accuracy: 0.7262 - precision: 0.7262 - recall: 0.7262 - auc: 0.8014 - f1_Score: 0.7182 - val_loss: 0.6845 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.6599 - val_f1_Score: 0.5928 - lr: 1.0000e-04 - 38s/epoch - 2s/step
# Epoch 21/75
# 25/25 - 33s - loss: 0.5584 - accuracy: 0.7200 - precision: 0.7200 - recall: 0.7200 - auc: 0.7884 - f1_Score: 0.7131 - val_loss: 0.6415 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7129 - val_f1_Score: 0.6437 - lr: 1.0000e-04 - 33s/epoch - 1s/step
# Epoch 22/75
# 25/25 - 35s - loss: 0.5562 - accuracy: 0.7138 - precision: 0.7138 - recall: 0.7138 - auc: 0.7882 - f1_Score: 0.7097 - val_loss: 0.5810 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7441 - val_f1_Score: 0.6156 - lr: 1.0000e-04 - 35s/epoch - 1s/step
# Epoch 23/75
# 25/25 - 35s - loss: 0.5278 - accuracy: 0.7412 - precision: 0.7412 - recall: 0.7412 - auc: 0.8161 - f1_Score: 0.7330 - val_loss: 0.6802 - val_accuracy: 0.6406 - val_precision: 0.6406 - val_recall: 0.6406 - val_auc: 0.6633 - val_f1_Score: 0.6197 - lr: 1.0000e-04 - 35s/epoch - 1s/step
# Epoch 24/75
# 25/25 - 35s - loss: 0.4858 - accuracy: 0.7638 - precision: 0.7638 - recall: 0.7638 - auc: 0.8504 - f1_Score: 0.7598 - val_loss: 0.9840 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5588 - val_f1_Score: 0.4688 - lr: 1.0000e-04 - 35s/epoch - 1s/step
# Epoch 25/75
# 25/25 - 37s - loss: 0.4690 - accuracy: 0.7763 - precision: 0.7763 - recall: 0.7763 - auc: 0.8597 - f1_Score: 0.7717 - val_loss: 0.9455 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.6802 - val_f1_Score: 0.5000 - lr: 1.0000e-04 - 37s/epoch - 1s/step
# Epoch 26/75
# 25/25 - 37s - loss: 0.4739 - accuracy: 0.7788 - precision: 0.7788 - recall: 0.7788 - auc: 0.8553 - f1_Score: 0.7752 - val_loss: 0.7164 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7258 - val_f1_Score: 0.6135 - lr: 1.0000e-04 - 37s/epoch - 1s/step
# Epoch 27/75
# 25/25 - 34s - loss: 0.4237 - accuracy: 0.7937 - precision: 0.7937 - recall: 0.7937 - auc: 0.8872 - f1_Score: 0.7904 - val_loss: 0.9821 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5955 - val_f1_Score: 0.4910 - lr: 1.0000e-04 - 34s/epoch - 1s/step
# Epoch 28/75
# 25/25 - 32s - loss: 0.3527 - accuracy: 0.8575 - precision: 0.8575 - recall: 0.8575 - auc: 0.9270 - f1_Score: 0.8548 - val_loss: 0.6135 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7781 - val_f1_Score: 0.6679 - lr: 3.1623e-05 - 32s/epoch - 1s/step
# Epoch 29/75
# 25/25 - 32s - loss: 0.3520 - accuracy: 0.8537 - precision: 0.8537 - recall: 0.8537 - auc: 0.9241 - f1_Score: 0.8518 - val_loss: 0.7711 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.7319 - val_f1_Score: 0.6971 - lr: 3.1623e-05 - 32s/epoch - 1s/step
# Epoch 30/75
# 25/25 - 35s - loss: 0.3140 - accuracy: 0.8700 - precision: 0.8700 - recall: 0.8700 - auc: 0.9410 - f1_Score: 0.8686 - val_loss: 0.7216 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7319 - val_f1_Score: 0.6699 - lr: 3.1623e-05 - 35s/epoch - 1s/step
# Epoch 31/75
# 25/25 - 31s - loss: 0.2575 - accuracy: 0.9075 - precision: 0.9075 - recall: 0.9075 - auc: 0.9595 - f1_Score: 0.9066 - val_loss: 0.5694 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8374 - val_f1_Score: 0.7498 - lr: 3.1623e-05 - 31s/epoch - 1s/step
# Epoch 32/75
# 25/25 - 31s - loss: 0.2214 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9700 - f1_Score: 0.9187 - val_loss: 1.0263 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6738 - val_f1_Score: 0.5733 - lr: 3.1623e-05 - 31s/epoch - 1s/step
# Epoch 33/75
# 25/25 - 31s - loss: 0.2517 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9606 - f1_Score: 0.9110 - val_loss: 1.1702 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6482 - val_f1_Score: 0.6046 - lr: 3.1623e-05 - 31s/epoch - 1s/step
# Epoch 34/75
# 25/25 - 29s - loss: 0.2143 - accuracy: 0.9177 - precision: 0.9177 - recall: 0.9177 - auc: 0.9716 - f1_Score: 0.9163 - val_loss: 0.4948 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8752 - val_f1_Score: 0.7733 - lr: 3.1623e-05 - 29s/epoch - 1s/step
# Epoch 35/75
# 25/25 - 30s - loss: 0.2209 - accuracy: 0.9175 - precision: 0.9175 - recall: 0.9175 - auc: 0.9702 - f1_Score: 0.9161 - val_loss: 0.6161 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8422 - val_f1_Score: 0.7628 - lr: 3.1623e-05 - 30s/epoch - 1s/step
# Epoch 36/75
# 25/25 - 29s - loss: 0.1605 - accuracy: 0.9438 - precision: 0.9438 - recall: 0.9438 - auc: 0.9843 - f1_Score: 0.9426 - val_loss: 0.7434 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8101 - val_f1_Score: 0.7810 - lr: 3.1623e-05 - 29s/epoch - 1s/step
# Epoch 37/75
# 25/25 - 30s - loss: 0.1774 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9795 - f1_Score: 0.9343 - val_loss: 0.6931 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8296 - val_f1_Score: 0.7609 - lr: 3.1623e-05 - 30s/epoch - 1s/step
# Epoch 38/75
# 25/25 - 31s - loss: 0.1677 - accuracy: 0.9344 - precision: 0.9344 - recall: 0.9344 - auc: 0.9826 - f1_Score: 0.9332 - val_loss: 0.5112 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.9023 - val_f1_Score: 0.7928 - lr: 3.1623e-05 - 31s/epoch - 1s/step
# Epoch 39/75
# 25/25 - 29s - loss: 0.1437 - accuracy: 0.9513 - precision: 0.9513 - recall: 0.9513 - auc: 0.9869 - f1_Score: 0.9508 - val_loss: 0.6104 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8611 - val_f1_Score: 0.7810 - lr: 3.1623e-05 - 29s/epoch - 1s/step
# Epoch 40/75
# 25/25 - 29s - loss: 0.1599 - accuracy: 0.9370 - precision: 0.9370 - recall: 0.9370 - auc: 0.9838 - f1_Score: 0.9358 - val_loss: 0.8905 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7888 - val_f1_Score: 0.7085 - lr: 1.0000e-05 - 29s/epoch - 1s/step
# Epoch 41/75
# 25/25 - 29s - loss: 0.1328 - accuracy: 0.9602 - precision: 0.9602 - recall: 0.9602 - auc: 0.9883 - f1_Score: 0.9599 - val_loss: 0.8822 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7625 - val_f1_Score: 0.6699 - lr: 1.0000e-05 - 29s/epoch - 1s/step
# Epoch 42/75
# 25/25 - 31s - loss: 0.1106 - accuracy: 0.9663 - precision: 0.9663 - recall: 0.9663 - auc: 0.9920 - f1_Score: 0.9660 - val_loss: 0.9144 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.7883 - val_f1_Score: 0.7338 - lr: 1.0000e-05 - 31s/epoch - 1s/step
# Epoch 43/75
# 25/25 - 30s - loss: 0.1419 - accuracy: 0.9447 - precision: 0.9447 - recall: 0.9447 - auc: 0.9873 - f1_Score: 0.9444 - val_loss: 0.5742 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8826 - val_f1_Score: 0.8381 - lr: 1.0000e-05 - 30s/epoch - 1s/step
# Epoch 44/75
# 25/25 - 28s - loss: 0.1113 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9926 - f1_Score: 0.9547 - val_loss: 0.5125 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.8845 - val_f1_Score: 0.7023 - lr: 1.0000e-05 - 28s/epoch - 1s/step
# Epoch 45/75
# 25/25 - 27s - loss: 0.1416 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9863 - f1_Score: 0.9548 - val_loss: 0.5713 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8906 - val_f1_Score: 0.8281 - lr: 3.1623e-06 - 27s/epoch - 1s/step
# Epoch 46/75
# 25/25 - 29s - loss: 0.1243 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9898 - f1_Score: 0.9561 - val_loss: 0.8463 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.7981 - val_f1_Score: 0.7928 - lr: 3.1623e-06 - 29s/epoch - 1s/step
# Epoch 47/75
# 25/25 - 28s - loss: 0.1045 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - auc: 0.9934 - f1_Score: 0.9624 - val_loss: 0.6482 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8728 - val_f1_Score: 0.8260 - lr: 3.1623e-06 - 28s/epoch - 1s/step
# Epoch 48/75
# 25/25 - 27s - loss: 0.1106 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9907 - f1_Score: 0.9685 - val_loss: 0.8296 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8342 - val_f1_Score: 0.7478 - lr: 3.1623e-06 - 27s/epoch - 1s/step
# Epoch 49/75
# 25/25 - 28s - loss: 0.1438 - accuracy: 0.9473 - precision: 0.9473 - recall: 0.9473 - auc: 0.9854 - f1_Score: 0.9470 - val_loss: 0.8047 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8491 - val_f1_Score: 0.7851 - lr: 3.1623e-06 - 28s/epoch - 1s/step
# Epoch 50/75
# 25/25 - 28s - loss: 0.1403 - accuracy: 0.9538 - precision: 0.9538 - recall: 0.9538 - auc: 0.9871 - f1_Score: 0.9536 - val_loss: 0.4412 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9167 - val_f1_Score: 0.8436 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 51/75
# 25/25 - 29s - loss: 0.1069 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9911 - f1_Score: 0.9672 - val_loss: 0.8217 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8376 - val_f1_Score: 0.7642 - lr: 1.0000e-06 - 29s/epoch - 1s/step
# Epoch 52/75
# 25/25 - 28s - loss: 0.1030 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9937 - f1_Score: 0.9645 - val_loss: 0.9085 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8262 - val_f1_Score: 0.7333 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 53/75
# 25/25 - 30s - loss: 0.0838 - accuracy: 0.9737 - precision: 0.9737 - recall: 0.9737 - auc: 0.9954 - f1_Score: 0.9736 - val_loss: 0.4938 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9104 - val_f1_Score: 0.8095 - lr: 1.0000e-06 - 30s/epoch - 1s/step
# Epoch 54/75
# 25/25 - 27s - loss: 0.0995 - accuracy: 0.9640 - precision: 0.9640 - recall: 0.9640 - auc: 0.9940 - f1_Score: 0.9638 - val_loss: 0.3334 - val_accuracy: 0.8906 - val_precision: 0.8906 - val_recall: 0.8906 - val_auc: 0.9575 - val_f1_Score: 0.8904 - lr: 1.0000e-06 - 27s/epoch - 1s/step
# Epoch 55/75
# 25/25 - 28s - loss: 0.0992 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9941 - f1_Score: 0.9643 - val_loss: 0.7873 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8159 - val_f1_Score: 0.7944 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 56/75
# 25/25 - 28s - loss: 0.0905 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9951 - f1_Score: 0.9648 - val_loss: 0.8154 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8323 - val_f1_Score: 0.7778 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 57/75
# 25/25 - 28s - loss: 0.0913 - accuracy: 0.9787 - precision: 0.9787 - recall: 0.9787 - auc: 0.9931 - f1_Score: 0.9787 - val_loss: 0.5836 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8865 - val_f1_Score: 0.7928 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 58/75
# 25/25 - 27s - loss: 0.1082 - accuracy: 0.9663 - precision: 0.9663 - recall: 0.9663 - auc: 0.9922 - f1_Score: 0.9661 - val_loss: 1.0671 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.7747 - val_f1_Score: 0.7229 - lr: 1.0000e-06 - 27s/epoch - 1s/step
# Epoch 59/75
# 25/25 - 28s - loss: 0.1026 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9934 - f1_Score: 0.9686 - val_loss: 0.2833 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9648 - val_f1_Score: 0.8643 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 60/75
# 25/25 - 28s - loss: 0.1059 - accuracy: 0.9638 - precision: 0.9638 - recall: 0.9638 - auc: 0.9926 - f1_Score: 0.9636 - val_loss: 0.6572 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8772 - val_f1_Score: 0.8437 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 61/75
# 25/25 - 27s - loss: 0.0965 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9934 - f1_Score: 0.9673 - val_loss: 0.3281 - val_accuracy: 0.8906 - val_precision: 0.8906 - val_recall: 0.8906 - val_auc: 0.9534 - val_f1_Score: 0.8873 - lr: 1.0000e-06 - 27s/epoch - 1s/step
# Epoch 62/75
# 25/25 - 28s - loss: 0.1003 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9930 - f1_Score: 0.9684 - val_loss: 0.8248 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.8032 - val_f1_Score: 0.7142 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 63/75
# 25/25 - 28s - loss: 0.1057 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9920 - f1_Score: 0.9647 - val_loss: 0.7999 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8452 - val_f1_Score: 0.8078 - lr: 1.0000e-06 - 28s/epoch - 1s/step
# Epoch 64/75
# 25/25 - 27s - loss: 0.1160 - accuracy: 0.9575 - precision: 0.9575 - recall: 0.9575 - auc: 0.9912 - f1_Score: 0.9572 - val_loss: 0.4499 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9155 - val_f1_Score: 0.8749 - lr: 1.0000e-06 - 27s/epoch - 1s/step
# Epoch 65/75
# 25/25 - 27s - loss: 0.1002 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9930 - f1_Score: 0.9646 - val_loss: 0.6349 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8762 - val_f1_Score: 0.7758 - lr: 3.1623e-07 - 27s/epoch - 1s/step
# Epoch 66/75
# 25/25 - 27s - loss: 0.1224 - accuracy: 0.9614 - precision: 0.9614 - recall: 0.9614 - auc: 0.9904 - f1_Score: 0.9610 - val_loss: 0.6678 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8730 - val_f1_Score: 0.8381 - lr: 3.1623e-07 - 27s/epoch - 1s/step
# Epoch 67/75
# 25/25 - 28s - loss: 0.1199 - accuracy: 0.9663 - precision: 0.9663 - recall: 0.9663 - auc: 0.9892 - f1_Score: 0.9660 - val_loss: 1.1782 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7590 - val_f1_Score: 0.6825 - lr: 3.1623e-07 - 28s/epoch - 1s/step
# Epoch 68/75
# 25/25 - 27s - loss: 0.0928 - accuracy: 0.9725 - precision: 0.9725 - recall: 0.9725 - auc: 0.9936 - f1_Score: 0.9716 - val_loss: 0.6068 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8684 - val_f1_Score: 0.8436 - lr: 3.1623e-07 - 27s/epoch - 1s/step
# Epoch 69/75
# 25/25 - 27s - loss: 0.1092 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9929 - f1_Score: 0.9544 - val_loss: 0.9362 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7981 - val_f1_Score: 0.7143 - lr: 3.1623e-07 - 27s/epoch - 1s/step
# Epoch 70/75
# 25/25 - 28s - loss: 0.1086 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9933 - f1_Score: 0.9645 - val_loss: 0.5554 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8933 - val_f1_Score: 0.7804 - lr: 1.0000e-07 - 28s/epoch - 1s/step
# Epoch 71/75
# 25/25 - 27s - loss: 0.1044 - accuracy: 0.9576 - precision: 0.9576 - recall: 0.9576 - auc: 0.9933 - f1_Score: 0.9571 - val_loss: 0.6684 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8589 - val_f1_Score: 0.8125 - lr: 1.0000e-07 - 27s/epoch - 1s/step
# Epoch 72/75
# 25/25 - 28s - loss: 0.1070 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9920 - f1_Score: 0.9649 - val_loss: 0.5585 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8840 - val_f1_Score: 0.7851 - lr: 1.0000e-07 - 28s/epoch - 1s/step
# Epoch 73/75
# 25/25 - 27s - loss: 0.1127 - accuracy: 0.9575 - precision: 0.9575 - recall: 0.9575 - auc: 0.9912 - f1_Score: 0.9571 - val_loss: 1.2496 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7297 - val_f1_Score: 0.6712 - lr: 1.0000e-07 - 27s/epoch - 1s/step
# Epoch 74/75
# 25/25 - 27s - loss: 0.0963 - accuracy: 0.9638 - precision: 0.9638 - recall: 0.9638 - auc: 0.9945 - f1_Score: 0.9636 - val_loss: 0.7518 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8530 - val_f1_Score: 0.8118 - lr: 1.0000e-07 - 27s/epoch - 1s/step
# Epoch 75/75
# 25/25 - 27s - loss: 0.1089 - accuracy: 0.9613 - precision: 0.9613 - recall: 0.9613 - auc: 0.9915 - f1_Score: 0.9603 - val_loss: 0.5593 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8906 - val_f1_Score: 0.8381 - lr: 3.1623e-08 - 27s/epoch - 1s/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']
learning_rate = history.history['lr']
print("Train Accuracy:" ,train_accuracy)
print("val Accuracy:" ,val_accuracy)
print("Train Loss:" ,train_loss)
print("val Loss:" ,val_loss)
# Out:
# Train Accuracy: [0.5562499761581421, 0.5299999713897705, 0.550000011920929, 0.5425000190734863, 0.5334190130233765, 0.5562499761581421, 0.543749988079071, 0.5687500238418579, 0.5362499952316284, 0.5224999785423279, 0.5649999976158142, 0.5687500238418579, 0.5899999737739563, 0.6324999928474426, 0.5796915292739868, 0.6200000047683716, 0.606249988079071, 0.668749988079071, 0.6712499856948853, 0.7262499928474426, 0.7200000286102295, 0.7137500047683716, 0.7412499785423279, 0.7637500166893005, 0.7762500047683716, 0.7787500023841858, 0.793749988079071, 0.8575000166893005, 0.8537499904632568, 0.8700000047683716, 0.9075000286102295, 0.9200000166893005, 0.9125000238418579, 0.9177377820014954, 0.9175000190734863, 0.9437500238418579, 0.9350000023841858, 0.9344472885131836, 0.9512500166893005, 0.9370179772377014, 0.9601542353630066, 0.9662500023841858, 0.9447301030158997, 0.9549999833106995, 0.9549999833106995, 0.956250011920929, 0.9627249240875244, 0.96875, 0.9473007917404175, 0.9537500143051147, 0.9674999713897705, 0.9649999737739563, 0.9737499952316284, 0.9640102982521057, 0.9649999737739563, 0.9649999737739563, 0.9787499904632568, 0.9662500023841858, 0.96875, 0.9637500047683716, 0.9674999713897705, 0.96875, 0.9649999737739563, 0.9574999809265137, 0.9649999737739563, 0.9614396095275879, 0.9662500023841858, 0.9725000262260437, 0.955012857913971, 0.9649999737739563, 0.9575835466384888, 0.9649999737739563, 0.9574999809265137, 0.9637500047683716, 0.9612500071525574]
# val Accuracy: [0.453125, 0.4375, 0.609375, 0.578125, 0.421875, 0.5625, 0.453125, 0.53125, 0.453125, 0.578125, 0.484375, 0.609375, 0.734375, 0.46875, 0.515625, 0.4375, 0.609375, 0.65625, 0.65625, 0.625, 0.65625, 0.625, 0.640625, 0.515625, 0.625, 0.6875, 0.53125, 0.671875, 0.703125, 0.671875, 0.75, 0.59375, 0.609375, 0.78125, 0.765625, 0.78125, 0.765625, 0.796875, 0.78125, 0.71875, 0.671875, 0.734375, 0.84375, 0.734375, 0.828125, 0.796875, 0.828125, 0.75, 0.796875, 0.84375, 0.765625, 0.75, 0.8125, 0.890625, 0.796875, 0.78125, 0.796875, 0.734375, 0.875, 0.84375, 0.890625, 0.734375, 0.8125, 0.875, 0.78125, 0.84375, 0.6875, 0.84375, 0.71875, 0.78125, 0.8125, 0.796875, 0.671875, 0.8125, 0.84375]
# Train Loss: [0.7087923288345337, 0.7035925388336182, 0.689411461353302, 0.6937960982322693, 0.6945826411247253, 0.6913504004478455, 0.6897948980331421, 0.684805154800415, 0.697428822517395, 0.6885710954666138, 0.6722460389137268, 0.6745321154594421, 0.6653186082839966, 0.6430137753486633, 0.677397608757019, 0.6714968085289001, 0.6637976169586182, 0.6257359385490417, 0.6195229887962341, 0.5520724058151245, 0.5583509206771851, 0.5561758875846863, 0.5278176665306091, 0.4858012795448303, 0.4690096974372864, 0.47385188937187195, 0.4236820638179779, 0.35272547602653503, 0.35204121470451355, 0.31404104828834534, 0.2575451731681824, 0.22142493724822998, 0.2517456114292145, 0.21427592635154724, 0.22092561423778534, 0.16053909063339233, 0.17739978432655334, 0.16768045723438263, 0.14374488592147827, 0.15992270410060883, 0.13284452259540558, 0.11057812720537186, 0.14190390706062317, 0.11129964143037796, 0.14161404967308044, 0.12426885962486267, 0.10450029373168945, 0.11056726425886154, 0.14379413425922394, 0.14028392732143402, 0.10686439275741577, 0.10297909379005432, 0.08383908867835999, 0.09946794807910919, 0.09920311719179153, 0.09050648659467697, 0.09125760942697525, 0.10817436128854752, 0.10264568030834198, 0.10590627044439316, 0.09649071097373962, 0.10034801810979843, 0.10571472346782684, 0.1159624457359314, 0.10017845034599304, 0.12240181863307953, 0.11990758031606674, 0.09281556308269501, 0.10915329307317734, 0.10856039077043533, 0.10439880937337875, 0.10696890205144882, 0.11269018799066544, 0.09627486020326614, 0.1088751032948494]
# val Loss: [0.6950477361679077, 0.7041415572166443, 0.6764441132545471, 0.6803479790687561, 0.712173342704773, 0.6854665875434875, 0.7083316445350647, 0.7050975561141968, 0.7033228874206543, 0.6749194264411926, 0.6913717985153198, 0.6653490662574768, 0.6040012836456299, 0.7271095514297485, 0.7742209434509277, 0.7737680673599243, 0.6620784997940063, 0.6197240352630615, 0.5848369598388672, 0.684540867805481, 0.6415415406227112, 0.5809534788131714, 0.6802305579185486, 0.9840375185012817, 0.9454998970031738, 0.7163714170455933, 0.982059895992279, 0.6135199069976807, 0.771130383014679, 0.7215701341629028, 0.5694473385810852, 1.0263354778289795, 1.1701544523239136, 0.4948357343673706, 0.6160581111907959, 0.7433971166610718, 0.6931458711624146, 0.5111746788024902, 0.6104133725166321, 0.8904631733894348, 0.8822444677352905, 0.914435625076294, 0.5741571187973022, 0.5124881267547607, 0.5713375806808472, 0.8463125228881836, 0.6482390761375427, 0.829604983329773, 0.8046650886535645, 0.44124919176101685, 0.8217195272445679, 0.9085078835487366, 0.49378713965415955, 0.3333958387374878, 0.7873066663742065, 0.8153620958328247, 0.5836237668991089, 1.0670915842056274, 0.28327658772468567, 0.6572176218032837, 0.3281102776527405, 0.8248224854469299, 0.7998627424240112, 0.4499201774597168, 0.6348981857299805, 0.6678289175033569, 1.1782183647155762, 0.6067991256713867, 0.9362432956695557, 0.5554054379463196, 0.6683531999588013, 0.5584501028060913, 1.2496016025543213, 0.7517555952072144, 0.5592831373214722]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 35/35 [==============================] - 21s 443ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 83/83 [==============================] - 50s 593ms/step - loss: 0.0481 - accuracy: 0.9848 - precision: 0.9848 - recall: 0.9848 - auc: 0.9982 - f1_Score: 0.9847

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.04813728854060173
# Train Accuracy: 0.9848139882087708
# Train Precision: 0.9848139882087708
# Train Recall: 0.9848139882087708
# Train AUC: 0.9982417225837708
# Train F1_Score: 0.9846714735031128

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 35/35 [==============================] - 14s 405ms/step - loss: 0.6888 - accuracy: 0.7957 - precision: 0.7957 - recall: 0.7957 - auc: 0.8664 - f1_Score: 0.7946

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.6887713670730591
# Test Accuracy: 0.7956989407539368
# Test Precision: 0.7956989407539368
# Test Recall: 0.7956989407539368
# Test AUC: 0.866412878036499
# Test F1_Score: 0.7946436405181885

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#         fake       0.80      0.76      0.78       530
#         real       0.79      0.83      0.81       586
#
#     accuracy                           0.80      1116
#    macro avg       0.80      0.79      0.79      1116
# weighted avg       0.80      0.80      0.80      1116

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('EffectiveNetV2L.csv', index = False)
