# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/train'
validation_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 175
IMG_HEIGHT = 175
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.1,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 2634 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : fake
# 1 : real

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2B1 Model**
# ### i. Create a EfficientNetV2B1 Model

# %%
base_model = tf.keras.applications.EfficientNetV2B1(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(175,175,3),
                     include_preprocessing=True

                     )

base_model.trainable=True

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-b1 (Function  (None, 6, 6, 1280)       6931124
#  al)
#
#  batch_normalization_1 (Batc  (None, 6, 6, 1280)       8960
#  hNormalization)
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 512)               655872
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 7,760,438
# Trainable params: 7,682,966
# Non-trainable params: 77,472
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
early = tf.keras.callbacks.EarlyStopping( patience=10,
                                          min_delta=0.001,
                                          restore_best_weights=True)

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.8/dist-packages (0.19.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)
sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=25,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=75,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/75
# 25/25 - 34s - loss: 0.7158 - accuracy: 0.5238 - precision: 0.5238 - recall: 0.5238 - auc: 0.5299 - f1_Score: 0.5102 - val_loss: 0.6921 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4976 - val_f1_Score: 0.4325 - lr: 0.0010 - 34s/epoch - 1s/step
# Epoch 2/75
# 25/25 - 19s - loss: 0.7062 - accuracy: 0.5462 - precision: 0.5462 - recall: 0.5462 - auc: 0.5565 - f1_Score: 0.5392 - val_loss: 0.6723 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6392 - val_f1_Score: 0.3469 - lr: 0.0010 - 19s/epoch - 764ms/step
# Epoch 3/75
# 25/25 - 18s - loss: 0.7279 - accuracy: 0.5250 - precision: 0.5250 - recall: 0.5250 - auc: 0.5326 - f1_Score: 0.4891 - val_loss: 0.6908 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5276 - val_f1_Score: 0.3976 - lr: 0.0010 - 18s/epoch - 725ms/step
# Epoch 4/75
# 25/25 - 17s - loss: 0.6991 - accuracy: 0.5462 - precision: 0.5462 - recall: 0.5462 - auc: 0.5279 - f1_Score: 0.4350 - val_loss: 0.6894 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.5732 - val_f1_Score: 0.3535 - lr: 0.0010 - 17s/epoch - 660ms/step
# Epoch 5/75
# 25/25 - 16s - loss: 0.6963 - accuracy: 0.5387 - precision: 0.5387 - recall: 0.5387 - auc: 0.5255 - f1_Score: 0.4489 - val_loss: 0.6985 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5432 - val_f1_Score: 0.3333 - lr: 0.0010 - 16s/epoch - 651ms/step
# Epoch 6/75
# 25/25 - 16s - loss: 0.6952 - accuracy: 0.5238 - precision: 0.5238 - recall: 0.5238 - auc: 0.5249 - f1_Score: 0.3968 - val_loss: 0.6910 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5559 - val_f1_Score: 0.5146 - lr: 0.0010 - 16s/epoch - 648ms/step
# Epoch 7/75
# 25/25 - 16s - loss: 0.7009 - accuracy: 0.5013 - precision: 0.5013 - recall: 0.5013 - auc: 0.4955 - f1_Score: 0.4515 - val_loss: 0.6954 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5088 - val_f1_Score: 0.3333 - lr: 0.0010 - 16s/epoch - 648ms/step
# Epoch 8/75
# 25/25 - 16s - loss: 0.6886 - accuracy: 0.5475 - precision: 0.5475 - recall: 0.5475 - auc: 0.5601 - f1_Score: 0.3684 - val_loss: 0.6729 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7063 - val_f1_Score: 0.3962 - lr: 3.1623e-04 - 16s/epoch - 653ms/step
# Epoch 9/75
# 25/25 - 16s - loss: 0.6925 - accuracy: 0.5337 - precision: 0.5337 - recall: 0.5337 - auc: 0.5295 - f1_Score: 0.4025 - val_loss: 0.7022 - val_accuracy: 0.4219 - val_precision: 0.4219 - val_recall: 0.4219 - val_auc: 0.4163 - val_f1_Score: 0.2967 - lr: 3.1623e-04 - 16s/epoch - 649ms/step
# Epoch 10/75
# 25/25 - 16s - loss: 0.6899 - accuracy: 0.5412 - precision: 0.5412 - recall: 0.5412 - auc: 0.5455 - f1_Score: 0.4121 - val_loss: 0.6914 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5645 - val_f1_Score: 0.3402 - lr: 3.1623e-04 - 16s/epoch - 648ms/step
# Epoch 11/75
# 25/25 - 16s - loss: 0.6870 - accuracy: 0.5612 - precision: 0.5612 - recall: 0.5612 - auc: 0.5718 - f1_Score: 0.3997 - val_loss: 0.6878 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.5840 - val_f1_Score: 0.3600 - lr: 3.1623e-04 - 16s/epoch - 659ms/step
# Epoch 12/75
# 25/25 - 16s - loss: 0.6877 - accuracy: 0.5537 - precision: 0.5537 - recall: 0.5537 - auc: 0.5600 - f1_Score: 0.3664 - val_loss: 0.6814 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6125 - val_f1_Score: 0.3725 - lr: 3.1623e-04 - 16s/epoch - 644ms/step
# Epoch 13/75
# 25/25 - 16s - loss: 0.6845 - accuracy: 0.5694 - precision: 0.5694 - recall: 0.5694 - auc: 0.5725 - f1_Score: 0.4093 - val_loss: 0.6810 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.6433 - val_f1_Score: 0.3600 - lr: 1.0000e-04 - 16s/epoch - 634ms/step
# Epoch 14/75
# 25/25 - 16s - loss: 0.6947 - accuracy: 0.5213 - precision: 0.5213 - recall: 0.5213 - auc: 0.5217 - f1_Score: 0.3669 - val_loss: 0.6953 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5012 - val_f1_Score: 0.3191 - lr: 1.0000e-04 - 16s/epoch - 655ms/step
# Epoch 15/75
# 25/25 - 16s - loss: 0.6936 - accuracy: 0.5150 - precision: 0.5150 - recall: 0.5150 - auc: 0.5306 - f1_Score: 0.3638 - val_loss: 0.6905 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5640 - val_f1_Score: 0.3469 - lr: 1.0000e-04 - 16s/epoch - 651ms/step
# Epoch 16/75
# 25/25 - 16s - loss: 0.6910 - accuracy: 0.5337 - precision: 0.5337 - recall: 0.5337 - auc: 0.5485 - f1_Score: 0.3814 - val_loss: 0.6785 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6738 - val_f1_Score: 0.3786 - lr: 1.0000e-04 - 16s/epoch - 651ms/step
# Epoch 17/75
# 25/25 - 20s - loss: 0.6880 - accuracy: 0.5550 - precision: 0.5550 - recall: 0.5550 - auc: 0.5576 - f1_Score: 0.3789 - val_loss: 0.6901 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5720 - val_f1_Score: 0.3333 - lr: 1.0000e-04 - 20s/epoch - 790ms/step
# Epoch 18/75
# 25/25 - 17s - loss: 0.6873 - accuracy: 0.5400 - precision: 0.5400 - recall: 0.5400 - auc: 0.5628 - f1_Score: 0.3783 - val_loss: 0.6967 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4949 - val_f1_Score: 0.3043 - lr: 3.1623e-05 - 17s/epoch - 664ms/step
# Epoch 19/75
# 25/25 - 17s - loss: 0.6861 - accuracy: 0.5425 - precision: 0.5425 - recall: 0.5425 - auc: 0.5749 - f1_Score: 0.3684 - val_loss: 0.6852 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6045 - val_f1_Score: 0.3333 - lr: 3.1623e-05 - 17s/epoch - 668ms/step
# Epoch 20/75
# 25/25 - 17s - loss: 0.6876 - accuracy: 0.5450 - precision: 0.5450 - recall: 0.5450 - auc: 0.5600 - f1_Score: 0.3719 - val_loss: 0.6940 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5137 - val_f1_Score: 0.3263 - lr: 3.1623e-05 - 17s/epoch - 670ms/step
# Epoch 21/75
# 25/25 - 17s - loss: 0.6894 - accuracy: 0.5387 - precision: 0.5387 - recall: 0.5387 - auc: 0.5443 - f1_Score: 0.3644 - val_loss: 0.6992 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.4695 - val_f1_Score: 0.3118 - lr: 3.1623e-05 - 17s/epoch - 674ms/step
# Epoch 22/75
# 25/25 - 17s - loss: 0.6868 - accuracy: 0.5462 - precision: 0.5462 - recall: 0.5462 - auc: 0.5676 - f1_Score: 0.3725 - val_loss: 0.6875 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.5784 - val_f1_Score: 0.3043 - lr: 3.1623e-05 - 17s/epoch - 666ms/step
# Epoch 23/75
# 25/25 - 16s - loss: 0.6891 - accuracy: 0.5362 - precision: 0.5362 - recall: 0.5362 - auc: 0.5554 - f1_Score: 0.3700 - val_loss: 0.6926 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5330 - val_f1_Score: 0.3333 - lr: 1.0000e-05 - 16s/epoch - 657ms/step
# Epoch 24/75
# 25/25 - 17s - loss: 0.6868 - accuracy: 0.5550 - precision: 0.5550 - recall: 0.5550 - auc: 0.5626 - f1_Score: 0.3766 - val_loss: 0.6979 - val_accuracy: 0.4219 - val_precision: 0.4219 - val_recall: 0.4219 - val_auc: 0.5139 - val_f1_Score: 0.2967 - lr: 1.0000e-05 - 17s/epoch - 665ms/step
# Epoch 25/75
# 25/25 - 17s - loss: 0.6872 - accuracy: 0.5462 - precision: 0.5462 - recall: 0.5462 - auc: 0.5656 - f1_Score: 0.3770 - val_loss: 0.6815 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.6204 - val_f1_Score: 0.3600 - lr: 1.0000e-05 - 17s/epoch - 661ms/step
# Epoch 26/75
# 25/25 - 16s - loss: 0.6904 - accuracy: 0.5296 - precision: 0.5296 - recall: 0.5296 - auc: 0.5473 - f1_Score: 0.3628 - val_loss: 0.6677 - val_accuracy: 0.6406 - val_precision: 0.6406 - val_recall: 0.6406 - val_auc: 0.7690 - val_f1_Score: 0.3905 - lr: 1.0000e-05 - 16s/epoch - 638ms/step
# Epoch 27/75
# 25/25 - 16s - loss: 0.6857 - accuracy: 0.5630 - precision: 0.5630 - recall: 0.5630 - auc: 0.5713 - f1_Score: 0.3856 - val_loss: 0.6879 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5867 - val_f1_Score: 0.3333 - lr: 1.0000e-05 - 16s/epoch - 636ms/step
# Epoch 28/75
# 25/25 - 16s - loss: 0.6867 - accuracy: 0.5462 - precision: 0.5462 - recall: 0.5462 - auc: 0.5674 - f1_Score: 0.3747 - val_loss: 0.6834 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.5889 - val_f1_Score: 0.3535 - lr: 1.0000e-05 - 16s/epoch - 655ms/step
# Epoch 29/75
# 25/25 - 16s - loss: 0.6839 - accuracy: 0.5675 - precision: 0.5675 - recall: 0.5675 - auc: 0.5803 - f1_Score: 0.3725 - val_loss: 0.6979 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4875 - val_f1_Score: 0.3043 - lr: 1.0000e-05 - 16s/epoch - 659ms/step
# Epoch 30/75
# 25/25 - 16s - loss: 0.6816 - accuracy: 0.5675 - precision: 0.5675 - recall: 0.5675 - auc: 0.5910 - f1_Score: 0.3824 - val_loss: 0.6945 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5044 - val_f1_Score: 0.3191 - lr: 1.0000e-05 - 16s/epoch - 652ms/step
# Epoch 31/75
# 25/25 - 17s - loss: 0.6833 - accuracy: 0.5675 - precision: 0.5675 - recall: 0.5675 - auc: 0.5830 - f1_Score: 0.3824 - val_loss: 0.6897 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5701 - val_f1_Score: 0.3263 - lr: 1.0000e-05 - 17s/epoch - 681ms/step
# Epoch 32/75
# 25/25 - 16s - loss: 0.6847 - accuracy: 0.5525 - precision: 0.5525 - recall: 0.5525 - auc: 0.5746 - f1_Score: 0.3822 - val_loss: 0.6791 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6624 - val_f1_Score: 0.3469 - lr: 3.1623e-06 - 16s/epoch - 653ms/step
# Epoch 33/75
# 25/25 - 16s - loss: 0.6784 - accuracy: 0.5825 - precision: 0.5825 - recall: 0.5825 - auc: 0.6071 - f1_Score: 0.3867 - val_loss: 0.6840 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5952 - val_f1_Score: 0.3469 - lr: 3.1623e-06 - 16s/epoch - 650ms/step
# Epoch 34/75
# 25/25 - 17s - loss: 0.6824 - accuracy: 0.5550 - precision: 0.5550 - recall: 0.5550 - auc: 0.5887 - f1_Score: 0.3812 - val_loss: 0.6681 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7466 - val_f1_Score: 0.3846 - lr: 3.1623e-06 - 17s/epoch - 680ms/step
# Epoch 35/75
# 25/25 - 16s - loss: 0.6914 - accuracy: 0.5200 - precision: 0.5200 - recall: 0.5200 - auc: 0.5411 - f1_Score: 0.3579 - val_loss: 0.6899 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5601 - val_f1_Score: 0.3402 - lr: 3.1623e-06 - 16s/epoch - 657ms/step
# Epoch 36/75
# 25/25 - 17s - loss: 0.6895 - accuracy: 0.5450 - precision: 0.5450 - recall: 0.5450 - auc: 0.5544 - f1_Score: 0.3652 - val_loss: 0.6917 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.5332 - val_f1_Score: 0.3535 - lr: 3.1623e-06 - 17s/epoch - 668ms/step
# Epoch 37/75
# 25/25 - 16s - loss: 0.6849 - accuracy: 0.5525 - precision: 0.5525 - recall: 0.5525 - auc: 0.5749 - f1_Score: 0.3777 - val_loss: 0.6789 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6252 - val_f1_Score: 0.3725 - lr: 1.0000e-06 - 16s/epoch - 651ms/step
# Epoch 38/75
# 25/25 - 16s - loss: 0.6816 - accuracy: 0.5643 - precision: 0.5643 - recall: 0.5643 - auc: 0.5951 - f1_Score: 0.3814 - val_loss: 0.6836 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6172 - val_f1_Score: 0.3469 - lr: 1.0000e-06 - 16s/epoch - 644ms/step
# Epoch 39/75
# 25/25 - 17s - loss: 0.6889 - accuracy: 0.5300 - precision: 0.5300 - recall: 0.5300 - auc: 0.5501 - f1_Score: 0.3754 - val_loss: 0.6772 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.6614 - val_f1_Score: 0.3600 - lr: 1.0000e-06 - 17s/epoch - 660ms/step
# Epoch 40/75
# 25/25 - 16s - loss: 0.6943 - accuracy: 0.5088 - precision: 0.5088 - recall: 0.5088 - auc: 0.5300 - f1_Score: 0.3607 - val_loss: 0.6746 - val_accuracy: 0.5781 - val_precision: 0.5781 - val_recall: 0.5781 - val_auc: 0.6670 - val_f1_Score: 0.3663 - lr: 1.0000e-06 - 16s/epoch - 647ms/step
# Epoch 41/75
# 25/25 - 16s - loss: 0.6819 - accuracy: 0.5668 - precision: 0.5668 - recall: 0.5668 - auc: 0.5922 - f1_Score: 0.3826 - val_loss: 0.6817 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6094 - val_f1_Score: 0.3725 - lr: 1.0000e-06 - 16s/epoch - 638ms/step
# Epoch 42/75
# 25/25 - 16s - loss: 0.6855 - accuracy: 0.5617 - precision: 0.5617 - recall: 0.5617 - auc: 0.5737 - f1_Score: 0.3920 - val_loss: 0.6977 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4868 - val_f1_Score: 0.3043 - lr: 3.1623e-07 - 16s/epoch - 636ms/step
# Epoch 43/75
# 25/25 - 16s - loss: 0.6894 - accuracy: 0.5373 - precision: 0.5373 - recall: 0.5373 - auc: 0.5501 - f1_Score: 0.3710 - val_loss: 0.6724 - val_accuracy: 0.6406 - val_precision: 0.6406 - val_recall: 0.6406 - val_auc: 0.6870 - val_f1_Score: 0.3905 - lr: 3.1623e-07 - 16s/epoch - 628ms/step
# Epoch 44/75
# 25/25 - 16s - loss: 0.6833 - accuracy: 0.5638 - precision: 0.5638 - recall: 0.5638 - auc: 0.5857 - f1_Score: 0.3733 - val_loss: 0.6943 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.5259 - val_f1_Score: 0.3118 - lr: 3.1623e-07 - 16s/epoch - 654ms/step
# Epoch 45/75
# 25/25 - 16s - loss: 0.6844 - accuracy: 0.5612 - precision: 0.5612 - recall: 0.5612 - auc: 0.5782 - f1_Score: 0.3865 - val_loss: 0.6983 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.4905 - val_f1_Score: 0.3263 - lr: 3.1623e-07 - 16s/epoch - 650ms/step
# Epoch 46/75
# 25/25 - 16s - loss: 0.6773 - accuracy: 0.5835 - precision: 0.5835 - recall: 0.5835 - auc: 0.6152 - f1_Score: 0.3979 - val_loss: 0.6912 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.5354 - val_f1_Score: 0.3535 - lr: 3.1623e-07 - 16s/epoch - 621ms/step
# Epoch 47/75
# 25/25 - 16s - loss: 0.6877 - accuracy: 0.5347 - precision: 0.5347 - recall: 0.5347 - auc: 0.5615 - f1_Score: 0.3720 - val_loss: 0.6772 - val_accuracy: 0.5781 - val_precision: 0.5781 - val_recall: 0.5781 - val_auc: 0.6306 - val_f1_Score: 0.3663 - lr: 1.0000e-07 - 16s/epoch - 625ms/step
# Epoch 48/75
# 25/25 - 16s - loss: 0.6834 - accuracy: 0.5512 - precision: 0.5512 - recall: 0.5512 - auc: 0.5875 - f1_Score: 0.3725 - val_loss: 0.6963 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.5063 - val_f1_Score: 0.3118 - lr: 1.0000e-07 - 16s/epoch - 650ms/step
# Epoch 49/75
# 25/25 - 19s - loss: 0.6888 - accuracy: 0.5450 - precision: 0.5450 - recall: 0.5450 - auc: 0.5508 - f1_Score: 0.3770 - val_loss: 0.6841 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5984 - val_f1_Score: 0.3402 - lr: 1.0000e-07 - 19s/epoch - 747ms/step
# Epoch 50/75
# 25/25 - 16s - loss: 0.6896 - accuracy: 0.5337 - precision: 0.5337 - recall: 0.5337 - auc: 0.5467 - f1_Score: 0.3752 - val_loss: 0.6770 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.6389 - val_f1_Score: 0.3846 - lr: 1.0000e-07 - 16s/epoch - 647ms/step
# Epoch 51/75
# 25/25 - 16s - loss: 0.6802 - accuracy: 0.5688 - precision: 0.5688 - recall: 0.5688 - auc: 0.5978 - f1_Score: 0.3805 - val_loss: 0.6957 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.5063 - val_f1_Score: 0.3118 - lr: 1.0000e-07 - 16s/epoch - 653ms/step
# Epoch 52/75
# 25/25 - 16s - loss: 0.6852 - accuracy: 0.5373 - precision: 0.5373 - recall: 0.5373 - auc: 0.5700 - f1_Score: 0.3641 - val_loss: 0.6684 - val_accuracy: 0.6406 - val_precision: 0.6406 - val_recall: 0.6406 - val_auc: 0.7080 - val_f1_Score: 0.3905 - lr: 3.1623e-08 - 16s/epoch - 638ms/step
# Epoch 53/75
# 25/25 - 16s - loss: 0.6912 - accuracy: 0.5411 - precision: 0.5411 - recall: 0.5411 - auc: 0.5416 - f1_Score: 0.3796 - val_loss: 0.6813 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6299 - val_f1_Score: 0.3469 - lr: 3.1623e-08 - 16s/epoch - 640ms/step
# Epoch 54/75
# 25/25 - 17s - loss: 0.6906 - accuracy: 0.5412 - precision: 0.5412 - recall: 0.5412 - auc: 0.5444 - f1_Score: 0.3810 - val_loss: 0.6974 - val_accuracy: 0.3906 - val_precision: 0.3906 - val_recall: 0.3906 - val_auc: 0.4819 - val_f1_Score: 0.2809 - lr: 3.1623e-08 - 17s/epoch - 661ms/step
# Epoch 55/75
# 25/25 - 16s - loss: 0.6907 - accuracy: 0.5312 - precision: 0.5312 - recall: 0.5312 - auc: 0.5474 - f1_Score: 0.3697 - val_loss: 0.6887 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5623 - val_f1_Score: 0.3333 - lr: 3.1623e-08 - 16s/epoch - 649ms/step
# Epoch 56/75
# 25/25 - 16s - loss: 0.6818 - accuracy: 0.5713 - precision: 0.5713 - recall: 0.5713 - auc: 0.5883 - f1_Score: 0.3865 - val_loss: 0.6874 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5662 - val_f1_Score: 0.3263 - lr: 3.1623e-08 - 16s/epoch - 645ms/step
# Epoch 57/75
# 25/25 - 16s - loss: 0.6814 - accuracy: 0.5788 - precision: 0.5788 - recall: 0.5788 - auc: 0.5935 - f1_Score: 0.3949 - val_loss: 0.6718 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.6904 - val_f1_Score: 0.3962 - lr: 1.0000e-08 - 16s/epoch - 642ms/step
# Epoch 58/75
# 25/25 - 16s - loss: 0.6846 - accuracy: 0.5604 - precision: 0.5604 - recall: 0.5604 - auc: 0.5781 - f1_Score: 0.3844 - val_loss: 0.6802 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6292 - val_f1_Score: 0.3469 - lr: 1.0000e-08 - 16s/epoch - 627ms/step
# Epoch 59/75
# 25/25 - 16s - loss: 0.6876 - accuracy: 0.5437 - precision: 0.5437 - recall: 0.5437 - auc: 0.5615 - f1_Score: 0.3667 - val_loss: 0.6932 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.5159 - val_f1_Score: 0.3118 - lr: 1.0000e-08 - 16s/epoch - 648ms/step
# Epoch 60/75
# 25/25 - 16s - loss: 0.6878 - accuracy: 0.5501 - precision: 0.5501 - recall: 0.5501 - auc: 0.5574 - f1_Score: 0.3818 - val_loss: 0.6845 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5967 - val_f1_Score: 0.3263 - lr: 1.0000e-08 - 16s/epoch - 632ms/step
# Epoch 61/75
# 25/25 - 16s - loss: 0.6878 - accuracy: 0.5462 - precision: 0.5462 - recall: 0.5462 - auc: 0.5565 - f1_Score: 0.3607 - val_loss: 0.6865 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5571 - val_f1_Score: 0.3469 - lr: 1.0000e-08 - 16s/epoch - 643ms/step
# Epoch 62/75
# 25/25 - 16s - loss: 0.6832 - accuracy: 0.5638 - precision: 0.5638 - recall: 0.5638 - auc: 0.5834 - f1_Score: 0.3922 - val_loss: 0.6832 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.6121 - val_f1_Score: 0.3535 - lr: 3.1623e-09 - 16s/epoch - 641ms/step
# Epoch 63/75
# 25/25 - 16s - loss: 0.6874 - accuracy: 0.5412 - precision: 0.5412 - recall: 0.5412 - auc: 0.5661 - f1_Score: 0.3655 - val_loss: 0.6925 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5400 - val_f1_Score: 0.3333 - lr: 3.1623e-09 - 16s/epoch - 656ms/step
# Epoch 64/75
# 25/25 - 18s - loss: 0.6851 - accuracy: 0.5500 - precision: 0.5500 - recall: 0.5500 - auc: 0.5766 - f1_Score: 0.3695 - val_loss: 0.6646 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7222 - val_f1_Score: 0.4019 - lr: 3.1623e-09 - 18s/epoch - 738ms/step
# Epoch 65/75
# 25/25 - 16s - loss: 0.6886 - accuracy: 0.5362 - precision: 0.5362 - recall: 0.5362 - auc: 0.5602 - f1_Score: 0.3700 - val_loss: 0.6756 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6592 - val_f1_Score: 0.3725 - lr: 3.1623e-09 - 16s/epoch - 642ms/step
# Epoch 66/75
# 25/25 - 16s - loss: 0.6868 - accuracy: 0.5512 - precision: 0.5512 - recall: 0.5512 - auc: 0.5650 - f1_Score: 0.3794 - val_loss: 0.6886 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5771 - val_f1_Score: 0.3402 - lr: 3.1623e-09 - 16s/epoch - 644ms/step
# Epoch 67/75
# 25/25 - 16s - loss: 0.6847 - accuracy: 0.5487 - precision: 0.5487 - recall: 0.5487 - auc: 0.5754 - f1_Score: 0.3736 - val_loss: 0.6887 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5811 - val_f1_Score: 0.3333 - lr: 3.1623e-09 - 16s/epoch - 641ms/step
# Epoch 68/75
# 25/25 - 16s - loss: 0.6842 - accuracy: 0.5562 - precision: 0.5562 - recall: 0.5562 - auc: 0.5769 - f1_Score: 0.3700 - val_loss: 0.6846 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.5920 - val_f1_Score: 0.3600 - lr: 3.1623e-09 - 16s/epoch - 644ms/step
# Epoch 69/75
# 25/25 - 16s - loss: 0.6859 - accuracy: 0.5663 - precision: 0.5663 - recall: 0.5663 - auc: 0.5701 - f1_Score: 0.3842 - val_loss: 0.6824 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6035 - val_f1_Score: 0.3469 - lr: 3.1623e-09 - 16s/epoch - 635ms/step
# Epoch 70/75
# 25/25 - 16s - loss: 0.6838 - accuracy: 0.5501 - precision: 0.5501 - recall: 0.5501 - auc: 0.5778 - f1_Score: 0.3748 - val_loss: 0.6658 - val_accuracy: 0.6406 - val_precision: 0.6406 - val_recall: 0.6406 - val_auc: 0.7153 - val_f1_Score: 0.3905 - lr: 1.0000e-09 - 16s/epoch - 622ms/step
# Epoch 71/75
# 25/25 - 16s - loss: 0.6833 - accuracy: 0.5566 - precision: 0.5566 - recall: 0.5566 - auc: 0.5865 - f1_Score: 0.3826 - val_loss: 0.6891 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5696 - val_f1_Score: 0.3263 - lr: 1.0000e-09 - 16s/epoch - 633ms/step
# Epoch 72/75
# 25/25 - 16s - loss: 0.6840 - accuracy: 0.5630 - precision: 0.5630 - recall: 0.5630 - auc: 0.5798 - f1_Score: 0.3733 - val_loss: 0.6896 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5652 - val_f1_Score: 0.3263 - lr: 1.0000e-09 - 16s/epoch - 630ms/step
# Epoch 73/75
# 25/25 - 16s - loss: 0.6872 - accuracy: 0.5476 - precision: 0.5476 - recall: 0.5476 - auc: 0.5677 - f1_Score: 0.3850 - val_loss: 0.6790 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.6355 - val_f1_Score: 0.3535 - lr: 1.0000e-09 - 16s/epoch - 627ms/step
# Epoch 74/75
# 25/25 - 16s - loss: 0.6884 - accuracy: 0.5487 - precision: 0.5487 - recall: 0.5487 - auc: 0.5528 - f1_Score: 0.3932 - val_loss: 0.6882 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5747 - val_f1_Score: 0.3333 - lr: 1.0000e-09 - 16s/epoch - 637ms/step
# Epoch 75/75
# 25/25 - 17s - loss: 0.6907 - accuracy: 0.5275 - precision: 0.5275 - recall: 0.5275 - auc: 0.5443 - f1_Score: 0.3592 - val_loss: 0.6712 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.6821 - val_f1_Score: 0.3846 - lr: 3.1623e-10 - 17s/epoch - 660ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']
learning_rate = history.history['lr']
print("Train Accuracy:" ,train_accuracy)
print("val Accuracy:" ,val_accuracy)
print("Train Loss:" ,train_loss)
print("val Loss:" ,val_loss)
# Out:
# Train Accuracy: [0.5237500071525574, 0.5462499856948853, 0.5249999761581421, 0.5462499856948853, 0.5387499928474426, 0.5237500071525574, 0.5012500286102295, 0.5475000143051147, 0.5337499976158142, 0.5412499904632568, 0.5612499713897705, 0.5537499785423279, 0.5694087147712708, 0.5212500095367432, 0.5149999856948853, 0.5337499976158142, 0.5550000071525574, 0.5400000214576721, 0.5425000190734863, 0.5450000166893005, 0.5387499928474426, 0.5462499856948853, 0.5362499952316284, 0.5550000071525574, 0.5462499856948853, 0.5295630097389221, 0.5629820227622986, 0.5462499856948853, 0.5674999952316284, 0.5674999952316284, 0.5674999952316284, 0.5525000095367432, 0.5824999809265137, 0.5550000071525574, 0.5199999809265137, 0.544987142086029, 0.5525000095367432, 0.5642673373222351, 0.5299999713897705, 0.5087500214576721, 0.5668380260467529, 0.5616966485977173, 0.5372750759124756, 0.5637500286102295, 0.5612499713897705, 0.5835475325584412, 0.5347043871879578, 0.5512499809265137, 0.544987142086029, 0.5337499976158142, 0.5687500238418579, 0.5372750759124756, 0.5411310791969299, 0.5412499904632568, 0.53125, 0.5712500214576721, 0.5787500143051147, 0.5604113340377808, 0.543749988079071, 0.5501285195350647, 0.5462499856948853, 0.5637500286102295, 0.5412499904632568, 0.550000011920929, 0.5362499952316284, 0.5512499809265137, 0.5487499833106995, 0.5562499761581421, 0.5662500262260437, 0.5501285195350647, 0.5565552711486816, 0.5629820227622986, 0.5475578308105469, 0.5487499833106995, 0.5274999737739563]
# val Accuracy: [0.4375, 0.53125, 0.46875, 0.546875, 0.5, 0.515625, 0.5, 0.65625, 0.421875, 0.515625, 0.5625, 0.59375, 0.5625, 0.46875, 0.53125, 0.609375, 0.5, 0.4375, 0.5, 0.484375, 0.453125, 0.4375, 0.5, 0.421875, 0.5625, 0.640625, 0.5, 0.546875, 0.4375, 0.46875, 0.484375, 0.53125, 0.53125, 0.625, 0.515625, 0.546875, 0.59375, 0.53125, 0.5625, 0.578125, 0.59375, 0.4375, 0.640625, 0.453125, 0.484375, 0.546875, 0.578125, 0.453125, 0.515625, 0.625, 0.453125, 0.640625, 0.53125, 0.390625, 0.5, 0.484375, 0.65625, 0.53125, 0.453125, 0.484375, 0.53125, 0.546875, 0.5, 0.671875, 0.59375, 0.515625, 0.5, 0.5625, 0.53125, 0.640625, 0.484375, 0.484375, 0.546875, 0.5, 0.625]
# Train Loss: [0.7158273458480835, 0.7061886787414551, 0.7279132604598999, 0.6990534067153931, 0.6963027715682983, 0.6951822638511658, 0.7008806467056274, 0.6886419653892517, 0.6925240159034729, 0.6899391412734985, 0.6869526505470276, 0.6877058148384094, 0.684485137462616, 0.6947386264801025, 0.6936158537864685, 0.6909816861152649, 0.6879746317863464, 0.6872749328613281, 0.6861112713813782, 0.6876300573348999, 0.6894460916519165, 0.6867883801460266, 0.6891463994979858, 0.686849057674408, 0.687196671962738, 0.6903806328773499, 0.6856536269187927, 0.6867495775222778, 0.6839447021484375, 0.6816463470458984, 0.6832597255706787, 0.6847416162490845, 0.6783618330955505, 0.6823589205741882, 0.6914377808570862, 0.6895362734794617, 0.6849328875541687, 0.681628406047821, 0.6889492869377136, 0.6943342685699463, 0.681879997253418, 0.6854690313339233, 0.6894207000732422, 0.6832514405250549, 0.6844364404678345, 0.6773203015327454, 0.6877320408821106, 0.6834468245506287, 0.6888372302055359, 0.6895911693572998, 0.6802024245262146, 0.6852130889892578, 0.6911866664886475, 0.690644383430481, 0.690684974193573, 0.6818211078643799, 0.6813926696777344, 0.684627890586853, 0.6876078248023987, 0.6877502799034119, 0.6877994537353516, 0.6832392811775208, 0.687375009059906, 0.6850953698158264, 0.6885952949523926, 0.6867762207984924, 0.684712827205658, 0.6841866374015808, 0.6858585476875305, 0.6837889552116394, 0.6833387613296509, 0.6839951872825623, 0.6872298121452332, 0.688425600528717, 0.6906833052635193]
# val Loss: [0.6921027302742004, 0.6723295450210571, 0.6908174753189087, 0.6893970370292664, 0.6985012292861938, 0.6910245418548584, 0.695415735244751, 0.6729353070259094, 0.7022435069084167, 0.6913884878158569, 0.6878356337547302, 0.6814438104629517, 0.6809855699539185, 0.6952812671661377, 0.6904537677764893, 0.6784713864326477, 0.690068244934082, 0.6966903209686279, 0.6852288246154785, 0.6939926743507385, 0.6991609334945679, 0.687465488910675, 0.6925584673881531, 0.6979353427886963, 0.6815263032913208, 0.6677334904670715, 0.6879379749298096, 0.6834425926208496, 0.6978671550750732, 0.6945304870605469, 0.6897155046463013, 0.6791401505470276, 0.6839505434036255, 0.6680710315704346, 0.6898980140686035, 0.6916717290878296, 0.678941547870636, 0.6836328506469727, 0.6772441864013672, 0.6745924949645996, 0.6817367076873779, 0.6976515054702759, 0.6723593473434448, 0.6942659020423889, 0.6983493566513062, 0.6911622881889343, 0.6772013902664185, 0.6963123083114624, 0.6840976476669312, 0.6769805550575256, 0.6956683397293091, 0.6684210300445557, 0.681276261806488, 0.6974474191665649, 0.6887022256851196, 0.6874167919158936, 0.6717501878738403, 0.6802434325218201, 0.6931936144828796, 0.6844806671142578, 0.6865326166152954, 0.6831620931625366, 0.6924892663955688, 0.6645964980125427, 0.6755508780479431, 0.6886093020439148, 0.6886652708053589, 0.684566855430603, 0.6824452877044678, 0.665795624256134, 0.689122200012207, 0.6896296739578247, 0.6789695024490356, 0.6881716251373291, 0.6712319254875183]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 35/35 [==============================] - 21s 544ms/step

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
print("done")
# Out:
# 83/83 [==============================] - 48s 577ms/step - loss: 0.6843 - accuracy: 0.5482 - precision: 0.5482 - recall: 0.5482 - auc: 0.5947 - f1_Score: 0.3541
# done

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.684256911277771
# Train Accuracy: 0.5482156276702881
# Train Precision: 0.5482156276702881
# Train Recall: 0.5482156276702881
# Train AUC: 0.594742476940155
# Train F1_Score: 0.35409513115882874

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 35/35 [==============================] - 16s 464ms/step - loss: 0.6849 - accuracy: 0.5251 - precision: 0.5251 - recall: 0.5251 - auc: 0.5929 - f1_Score: 0.3443

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.6849448680877686
# Test Accuracy: 0.5250896215438843
# Test Precision: 0.5250896215438843
# Test Recall: 0.5250896215438843
# Test AUC: 0.5929133892059326
# Test F1_Score: 0.3443008363246918

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#         fake       0.00      0.00      0.00       530
#         real       0.53      1.00      0.69       586
#
#     accuracy                           0.53      1116
#    macro avg       0.26      0.50      0.34      1116
# weighted avg       0.28      0.53      0.36      1116

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('EffectiveNetV2B1.csv', index = False)
