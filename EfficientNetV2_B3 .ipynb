# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/train'
validation_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 175
IMG_HEIGHT = 175
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.1,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 2634 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : fake
# 1 : real

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2B3 Model**
#
#
# ### i. Create a EfficientNetV2B3 Model

# %%
base_model = tf.keras.applications.EfficientNetV2B3(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(175,175,3),
                     include_preprocessing=True

                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 [==============================] - 0s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-b3 (Function  (None, 6, 6, 1536)       12930622
#  al)
#
#  batch_normalization_1 (Batc  (None, 6, 6, 1536)       10752
#  hNormalization)
#
#  global_average_pooling2d_1   (None, 1536)             0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 512)               786944
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 13,892,800
# Trainable params: 13,775,904
# Non-trainable params: 116,896
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
early = tf.keras.callbacks.EarlyStopping( patience=10,
                                          min_delta=0.001,
                                          restore_best_weights=True)

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.8/dist-packages (0.19.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)
sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=25,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=75,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/75
# 25/25 - 50s - loss: 0.7368 - accuracy: 0.5188 - precision: 0.5188 - recall: 0.5188 - auc: 0.5183 - f1_Score: 0.5086 - val_loss: 0.6955 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5063 - val_f1_Score: 0.3402 - lr: 0.0010 - 50s/epoch - 2s/step
# Epoch 2/75
# 25/25 - 16s - loss: 0.7134 - accuracy: 0.5138 - precision: 0.5138 - recall: 0.5138 - auc: 0.5149 - f1_Score: 0.4977 - val_loss: 0.8547 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5051 - val_f1_Score: 0.3191 - lr: 0.0010 - 16s/epoch - 651ms/step
# Epoch 3/75
# 25/25 - 16s - loss: 0.7088 - accuracy: 0.5163 - precision: 0.5163 - recall: 0.5163 - auc: 0.5391 - f1_Score: 0.5003 - val_loss: 0.6958 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.4344 - val_f1_Score: 0.3191 - lr: 0.0010 - 16s/epoch - 652ms/step
# Epoch 4/75
# 25/25 - 19s - loss: 0.7068 - accuracy: 0.5334 - precision: 0.5334 - recall: 0.5334 - auc: 0.5255 - f1_Score: 0.4711 - val_loss: 0.7082 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5254 - val_f1_Score: 0.3191 - lr: 0.0010 - 19s/epoch - 743ms/step
# Epoch 5/75
# 25/25 - 16s - loss: 0.6948 - accuracy: 0.5487 - precision: 0.5487 - recall: 0.5487 - auc: 0.5426 - f1_Score: 0.4350 - val_loss: 0.6690 - val_accuracy: 0.6406 - val_precision: 0.6406 - val_recall: 0.6406 - val_auc: 0.6849 - val_f1_Score: 0.4873 - lr: 0.0010 - 16s/epoch - 656ms/step
# Epoch 6/75
# 25/25 - 16s - loss: 0.6992 - accuracy: 0.5476 - precision: 0.5476 - recall: 0.5476 - auc: 0.5502 - f1_Score: 0.4438 - val_loss: 0.6869 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.5806 - val_f1_Score: 0.3535 - lr: 0.0010 - 16s/epoch - 645ms/step
# Epoch 7/75
# 25/25 - 16s - loss: 0.6922 - accuracy: 0.5362 - precision: 0.5362 - recall: 0.5362 - auc: 0.5437 - f1_Score: 0.4956 - val_loss: 0.6946 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4482 - val_f1_Score: 0.3043 - lr: 0.0010 - 16s/epoch - 655ms/step
# Epoch 8/75
# 25/25 - 16s - loss: 0.6915 - accuracy: 0.5617 - precision: 0.5617 - recall: 0.5617 - auc: 0.5738 - f1_Score: 0.4619 - val_loss: 0.6872 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6123 - val_f1_Score: 0.3725 - lr: 0.0010 - 16s/epoch - 636ms/step
# Epoch 9/75
# 25/25 - 16s - loss: 0.6853 - accuracy: 0.5600 - precision: 0.5600 - recall: 0.5600 - auc: 0.5848 - f1_Score: 0.5325 - val_loss: 0.7611 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.4937 - val_f1_Score: 0.3469 - lr: 0.0010 - 16s/epoch - 654ms/step
# Epoch 10/75
# 25/25 - 16s - loss: 0.6910 - accuracy: 0.5562 - precision: 0.5562 - recall: 0.5562 - auc: 0.5755 - f1_Score: 0.5052 - val_loss: 0.6956 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5386 - val_f1_Score: 0.3469 - lr: 0.0010 - 16s/epoch - 656ms/step
# Epoch 11/75
# 25/25 - 17s - loss: 0.6837 - accuracy: 0.5562 - precision: 0.5562 - recall: 0.5562 - auc: 0.5870 - f1_Score: 0.5061 - val_loss: 0.6904 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5419 - val_f1_Score: 0.3818 - lr: 3.1623e-04 - 17s/epoch - 662ms/step
# Epoch 12/75
# 25/25 - 16s - loss: 0.6681 - accuracy: 0.5913 - precision: 0.5913 - recall: 0.5913 - auc: 0.6358 - f1_Score: 0.5399 - val_loss: 0.7061 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.5464 - val_f1_Score: 0.3600 - lr: 3.1623e-04 - 16s/epoch - 630ms/step
# Epoch 13/75
# 25/25 - 16s - loss: 0.6751 - accuracy: 0.5951 - precision: 0.5951 - recall: 0.5951 - auc: 0.6229 - f1_Score: 0.5691 - val_loss: 0.6604 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6338 - val_f1_Score: 0.6015 - lr: 3.1623e-04 - 16s/epoch - 647ms/step
# Epoch 14/75
# 25/25 - 16s - loss: 0.6539 - accuracy: 0.6093 - precision: 0.6093 - recall: 0.6093 - auc: 0.6593 - f1_Score: 0.5822 - val_loss: 0.6269 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7546 - val_f1_Score: 0.6607 - lr: 3.1623e-04 - 16s/epoch - 636ms/step
# Epoch 15/75
# 25/25 - 16s - loss: 0.6471 - accuracy: 0.6285 - precision: 0.6285 - recall: 0.6285 - auc: 0.6730 - f1_Score: 0.6020 - val_loss: 0.6348 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7278 - val_f1_Score: 0.5072 - lr: 3.1623e-04 - 16s/epoch - 640ms/step
# Epoch 16/75
# 25/25 - 16s - loss: 0.6562 - accuracy: 0.6125 - precision: 0.6125 - recall: 0.6125 - auc: 0.6652 - f1_Score: 0.5976 - val_loss: 0.6352 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7178 - val_f1_Score: 0.6323 - lr: 3.1623e-04 - 16s/epoch - 655ms/step
# Epoch 17/75
# 25/25 - 16s - loss: 0.6232 - accuracy: 0.6594 - precision: 0.6594 - recall: 0.6594 - auc: 0.7131 - f1_Score: 0.6544 - val_loss: 0.7210 - val_accuracy: 0.5781 - val_precision: 0.5781 - val_recall: 0.5781 - val_auc: 0.5745 - val_f1_Score: 0.5461 - lr: 3.1623e-04 - 16s/epoch - 637ms/step
# Epoch 18/75
# 25/25 - 16s - loss: 0.5935 - accuracy: 0.6928 - precision: 0.6928 - recall: 0.6928 - auc: 0.7507 - f1_Score: 0.6811 - val_loss: 0.8193 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.5715 - val_f1_Score: 0.5377 - lr: 3.1623e-04 - 16s/epoch - 633ms/step
# Epoch 19/75
# 25/25 - 16s - loss: 0.6114 - accuracy: 0.6851 - precision: 0.6851 - recall: 0.6851 - auc: 0.7419 - f1_Score: 0.6671 - val_loss: 0.6271 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6996 - val_f1_Score: 0.4793 - lr: 3.1623e-04 - 16s/epoch - 638ms/step
# Epoch 20/75
# 25/25 - 16s - loss: 0.5988 - accuracy: 0.7075 - precision: 0.7075 - recall: 0.7075 - auc: 0.7519 - f1_Score: 0.6923 - val_loss: 0.5826 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.7664 - val_f1_Score: 0.6903 - lr: 1.0000e-04 - 16s/epoch - 655ms/step
# Epoch 21/75
# 25/25 - 16s - loss: 0.5454 - accuracy: 0.7147 - precision: 0.7147 - recall: 0.7147 - auc: 0.8048 - f1_Score: 0.7036 - val_loss: 0.6074 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7562 - val_f1_Score: 0.6679 - lr: 1.0000e-04 - 16s/epoch - 642ms/step
# Epoch 22/75
# 25/25 - 16s - loss: 0.5722 - accuracy: 0.7138 - precision: 0.7138 - recall: 0.7138 - auc: 0.7750 - f1_Score: 0.7070 - val_loss: 0.5790 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.7820 - val_f1_Score: 0.7793 - lr: 1.0000e-04 - 16s/epoch - 646ms/step
# Epoch 23/75
# 25/25 - 16s - loss: 0.5340 - accuracy: 0.7500 - precision: 0.7500 - recall: 0.7500 - auc: 0.8142 - f1_Score: 0.7462 - val_loss: 0.9970 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5878 - val_f1_Score: 0.5077 - lr: 1.0000e-04 - 16s/epoch - 656ms/step
# Epoch 24/75
# 25/25 - 16s - loss: 0.4827 - accuracy: 0.7661 - precision: 0.7661 - recall: 0.7661 - auc: 0.8523 - f1_Score: 0.7639 - val_loss: 0.8110 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.7461 - val_f1_Score: 0.6865 - lr: 1.0000e-04 - 16s/epoch - 647ms/step
# Epoch 25/75
# 25/25 - 16s - loss: 0.4616 - accuracy: 0.7815 - precision: 0.7815 - recall: 0.7815 - auc: 0.8622 - f1_Score: 0.7792 - val_loss: 0.6181 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.7788 - val_f1_Score: 0.7312 - lr: 1.0000e-04 - 16s/epoch - 638ms/step
# Epoch 26/75
# 25/25 - 16s - loss: 0.4734 - accuracy: 0.7788 - precision: 0.7788 - recall: 0.7788 - auc: 0.8599 - f1_Score: 0.7762 - val_loss: 0.4846 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8464 - val_f1_Score: 0.8078 - lr: 1.0000e-04 - 16s/epoch - 659ms/step
# Epoch 27/75
# 25/25 - 16s - loss: 0.3982 - accuracy: 0.8450 - precision: 0.8450 - recall: 0.8450 - auc: 0.9048 - f1_Score: 0.8425 - val_loss: 0.5723 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7749 - val_f1_Score: 0.6508 - lr: 1.0000e-04 - 16s/epoch - 655ms/step
# Epoch 28/75
# 25/25 - 16s - loss: 0.4188 - accuracy: 0.8200 - precision: 0.8200 - recall: 0.8200 - auc: 0.8910 - f1_Score: 0.8157 - val_loss: 0.7420 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.6877 - val_f1_Score: 0.7013 - lr: 1.0000e-04 - 16s/epoch - 657ms/step
# Epoch 29/75
# 25/25 - 16s - loss: 0.4054 - accuracy: 0.8125 - precision: 0.8125 - recall: 0.8125 - auc: 0.8971 - f1_Score: 0.8089 - val_loss: 0.5496 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8171 - val_f1_Score: 0.7500 - lr: 1.0000e-04 - 16s/epoch - 650ms/step
# Epoch 30/75
# 25/25 - 16s - loss: 0.3969 - accuracy: 0.8303 - precision: 0.8303 - recall: 0.8303 - auc: 0.9040 - f1_Score: 0.8288 - val_loss: 0.6261 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.7764 - val_f1_Score: 0.6971 - lr: 1.0000e-04 - 16s/epoch - 648ms/step
# Epoch 31/75
# 25/25 - 16s - loss: 0.3558 - accuracy: 0.8512 - precision: 0.8512 - recall: 0.8512 - auc: 0.9223 - f1_Score: 0.8497 - val_loss: 0.5922 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7866 - val_f1_Score: 0.6559 - lr: 1.0000e-04 - 16s/epoch - 657ms/step
# Epoch 32/75
# 25/25 - 16s - loss: 0.3368 - accuracy: 0.8560 - precision: 0.8560 - recall: 0.8560 - auc: 0.9305 - f1_Score: 0.8552 - val_loss: 0.4585 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8680 - val_f1_Score: 0.7968 - lr: 3.1623e-05 - 16s/epoch - 639ms/step
# Epoch 33/75
# 25/25 - 16s - loss: 0.2884 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9512 - f1_Score: 0.8752 - val_loss: 0.4568 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8730 - val_f1_Score: 0.8095 - lr: 3.1623e-05 - 16s/epoch - 658ms/step
# Epoch 34/75
# 25/25 - 16s - loss: 0.2786 - accuracy: 0.8875 - precision: 0.8875 - recall: 0.8875 - auc: 0.9540 - f1_Score: 0.8868 - val_loss: 0.8994 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.7192 - val_f1_Score: 0.7025 - lr: 3.1623e-05 - 16s/epoch - 659ms/step
# Epoch 35/75
# 25/25 - 16s - loss: 0.3026 - accuracy: 0.8725 - precision: 0.8725 - recall: 0.8725 - auc: 0.9441 - f1_Score: 0.8717 - val_loss: 0.3469 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9309 - val_f1_Score: 0.8095 - lr: 3.1623e-05 - 16s/epoch - 649ms/step
# Epoch 36/75
# 25/25 - 16s - loss: 0.2902 - accuracy: 0.8850 - precision: 0.8850 - recall: 0.8850 - auc: 0.9487 - f1_Score: 0.8842 - val_loss: 0.7552 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.7422 - val_f1_Score: 0.7312 - lr: 3.1623e-05 - 16s/epoch - 652ms/step
# Epoch 37/75
# 25/25 - 16s - loss: 0.2441 - accuracy: 0.9062 - precision: 0.9062 - recall: 0.9062 - auc: 0.9654 - f1_Score: 0.9041 - val_loss: 0.5602 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8333 - val_f1_Score: 0.7813 - lr: 3.1623e-05 - 16s/epoch - 654ms/step
# Epoch 38/75
# 25/25 - 16s - loss: 0.2604 - accuracy: 0.8963 - precision: 0.8963 - recall: 0.8963 - auc: 0.9588 - f1_Score: 0.8948 - val_loss: 0.6537 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.7957 - val_f1_Score: 0.7642 - lr: 3.1623e-05 - 16s/epoch - 657ms/step
# Epoch 39/75
# 25/25 - 16s - loss: 0.1890 - accuracy: 0.9225 - precision: 0.9225 - recall: 0.9225 - auc: 0.9810 - f1_Score: 0.9214 - val_loss: 0.7629 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.7837 - val_f1_Score: 0.7656 - lr: 3.1623e-05 - 16s/epoch - 646ms/step
# Epoch 40/75
# 25/25 - 16s - loss: 0.2266 - accuracy: 0.9075 - precision: 0.9075 - recall: 0.9075 - auc: 0.9693 - f1_Score: 0.9071 - val_loss: 0.6044 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8551 - val_f1_Score: 0.7944 - lr: 3.1623e-05 - 16s/epoch - 644ms/step
# Epoch 41/75
# 25/25 - 17s - loss: 0.2043 - accuracy: 0.9150 - precision: 0.9150 - recall: 0.9150 - auc: 0.9756 - f1_Score: 0.9146 - val_loss: 0.6346 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8455 - val_f1_Score: 0.7851 - lr: 1.0000e-05 - 17s/epoch - 661ms/step
# Epoch 42/75
# 25/25 - 18s - loss: 0.2304 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9673 - f1_Score: 0.9101 - val_loss: 0.8984 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7488 - val_f1_Score: 0.7188 - lr: 1.0000e-05 - 18s/epoch - 702ms/step
# Epoch 43/75
# 25/25 - 16s - loss: 0.2139 - accuracy: 0.9137 - precision: 0.9137 - recall: 0.9137 - auc: 0.9727 - f1_Score: 0.9132 - val_loss: 0.5515 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8518 - val_f1_Score: 0.8123 - lr: 1.0000e-05 - 16s/epoch - 653ms/step
# Epoch 44/75
# 25/25 - 16s - loss: 0.1783 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9804 - f1_Score: 0.9330 - val_loss: 0.4714 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8821 - val_f1_Score: 0.8108 - lr: 1.0000e-06 - 16s/epoch - 653ms/step
# Epoch 53/75
# 25/25 - 18s - loss: 0.2093 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9730 - f1_Score: 0.9193 - val_loss: 0.5533 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8594 - val_f1_Score: 0.7409 - lr: 1.0000e-06 - 18s/epoch - 704ms/step
# Epoch 54/75
# 25/25 - 17s - loss: 0.2056 - accuracy: 0.9137 - precision: 0.9137 - recall: 0.9137 - auc: 0.9748 - f1_Score: 0.9134 - val_loss: 1.0902 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.6956 - val_f1_Score: 0.6872 - lr: 1.0000e-06 - 17s/epoch - 661ms/step
# Epoch 55/75
# 25/25 - 17s - loss: 0.1976 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9771 - f1_Score: 0.9117 - val_loss: 0.7290 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.8120 - val_f1_Score: 0.7327 - lr: 1.0000e-06 - 17s/epoch - 699ms/step
# Epoch 56/75
# 25/25 - 16s - loss: 0.1910 - accuracy: 0.9254 - precision: 0.9254 - recall: 0.9254 - auc: 0.9780 - f1_Score: 0.9246 - val_loss: 0.5683 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8560 - val_f1_Score: 0.7793 - lr: 3.1623e-07 - 16s/epoch - 639ms/step
# Epoch 57/75
# 25/25 - 16s - loss: 0.1815 - accuracy: 0.9237 - precision: 0.9237 - recall: 0.9237 - auc: 0.9807 - f1_Score: 0.9234 - val_loss: 0.6856 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8328 - val_f1_Score: 0.7460 - lr: 3.1623e-07 - 16s/epoch - 657ms/step
# Epoch 58/75
# 25/25 - 16s - loss: 0.1774 - accuracy: 0.9306 - precision: 0.9306 - recall: 0.9306 - auc: 0.9819 - f1_Score: 0.9299 - val_loss: 0.7877 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8137 - val_f1_Score: 0.7804 - lr: 3.1623e-07 - 16s/epoch - 645ms/step
# Epoch 59/75
# 25/25 - 16s - loss: 0.1795 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9800 - f1_Score: 0.9313 - val_loss: 0.6818 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8157 - val_f1_Score: 0.7309 - lr: 3.1623e-07 - 16s/epoch - 640ms/step
# Epoch 60/75
# 25/25 - 18s - loss: 0.1916 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9784 - f1_Score: 0.9261 - val_loss: 0.4408 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9045 - val_f1_Score: 0.8585 - lr: 3.1623e-07 - 18s/epoch - 705ms/step
# Epoch 61/75
# 25/25 - 16s - loss: 0.2138 - accuracy: 0.9100 - precision: 0.9100 - recall: 0.9100 - auc: 0.9727 - f1_Score: 0.9093 - val_loss: 0.4405 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9094 - val_f1_Score: 0.8247 - lr: 1.0000e-07 - 16s/epoch - 652ms/step
# Epoch 62/75
# 25/25 - 16s - loss: 0.1619 - accuracy: 0.9475 - precision: 0.9475 - recall: 0.9475 - auc: 0.9845 - f1_Score: 0.9471 - val_loss: 0.6485 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.8418 - val_f1_Score: 0.7143 - lr: 1.0000e-07 - 16s/epoch - 657ms/step
# Epoch 63/75
# 25/25 - 16s - loss: 0.1889 - accuracy: 0.9229 - precision: 0.9229 - recall: 0.9229 - auc: 0.9789 - f1_Score: 0.9224 - val_loss: 0.5074 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8845 - val_f1_Score: 0.7964 - lr: 1.0000e-07 - 16s/epoch - 642ms/step
# Epoch 64/75
# 25/25 - 17s - loss: 0.1868 - accuracy: 0.9388 - precision: 0.9388 - recall: 0.9388 - auc: 0.9781 - f1_Score: 0.9385 - val_loss: 0.6447 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8320 - val_f1_Score: 0.7478 - lr: 1.0000e-07 - 17s/epoch - 670ms/step
# Epoch 65/75
# 25/25 - 16s - loss: 0.1520 - accuracy: 0.9473 - precision: 0.9473 - recall: 0.9473 - auc: 0.9876 - f1_Score: 0.9468 - val_loss: 0.6744 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8394 - val_f1_Score: 0.7656 - lr: 1.0000e-07 - 16s/epoch - 637ms/step
# Epoch 66/75
# 25/25 - 16s - loss: 0.2029 - accuracy: 0.9175 - precision: 0.9175 - recall: 0.9175 - auc: 0.9751 - f1_Score: 0.9162 - val_loss: 0.5275 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8800 - val_f1_Score: 0.7968 - lr: 3.1623e-08 - 16s/epoch - 650ms/step
# Epoch 67/75
# 25/25 - 16s - loss: 0.1866 - accuracy: 0.9242 - precision: 0.9242 - recall: 0.9242 - auc: 0.9795 - f1_Score: 0.9237 - val_loss: 0.8660 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.7710 - val_f1_Score: 0.7460 - lr: 3.1623e-08 - 16s/epoch - 641ms/step
# Epoch 68/75
# 25/25 - 16s - loss: 0.1764 - accuracy: 0.9344 - precision: 0.9344 - recall: 0.9344 - auc: 0.9816 - f1_Score: 0.9340 - val_loss: 0.7541 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8230 - val_f1_Score: 0.7810 - lr: 3.1623e-08 - 16s/epoch - 645ms/step
# Epoch 69/75
# 25/25 - 16s - loss: 0.1556 - accuracy: 0.9425 - precision: 0.9425 - recall: 0.9425 - auc: 0.9872 - f1_Score: 0.9415 - val_loss: 0.4797 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8840 - val_f1_Score: 0.8381 - lr: 3.1623e-08 - 16s/epoch - 655ms/step
# Epoch 70/75
# 25/25 - 16s - loss: 0.2128 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9724 - f1_Score: 0.9112 - val_loss: 0.6019 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8772 - val_f1_Score: 0.7810 - lr: 3.1623e-08 - 16s/epoch - 653ms/step
# Epoch 71/75
# 25/25 - 16s - loss: 0.1816 - accuracy: 0.9300 - precision: 0.9300 - recall: 0.9300 - auc: 0.9805 - f1_Score: 0.9294 - val_loss: 0.5591 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8623 - val_f1_Score: 0.8277 - lr: 1.0000e-08 - 16s/epoch - 652ms/step
# Epoch 72/75
# 25/25 - 16s - loss: 0.1944 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9770 - f1_Score: 0.9334 - val_loss: 0.8183 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.7773 - val_f1_Score: 0.7490 - lr: 1.0000e-08 - 16s/epoch - 654ms/step
# Epoch 73/75
# 25/25 - 17s - loss: 0.1950 - accuracy: 0.9287 - precision: 0.9287 - recall: 0.9287 - auc: 0.9767 - f1_Score: 0.9276 - val_loss: 0.6950 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8196 - val_f1_Score: 0.7656 - lr: 1.0000e-08 - 17s/epoch - 662ms/step
# Epoch 74/75
# 25/25 - 16s - loss: 0.1659 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9842 - f1_Score: 0.9330 - val_loss: 0.8155 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7756 - val_f1_Score: 0.7176 - lr: 1.0000e-08 - 16s/epoch - 650ms/step
# Epoch 75/75
# 25/25 - 16s - loss: 0.1893 - accuracy: 0.9237 - precision: 0.9237 - recall: 0.9237 - auc: 0.9782 - f1_Score: 0.9232 - val_loss: 0.4105 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9113 - val_f1_Score: 0.8413 - lr: 1.0000e-08 - 16s/epoch - 658ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 35/35 [==============================] - 23s 601ms/step

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
print("done")
# Out:
# 83/83 [==============================] - 55s 651ms/step - loss: 0.0932 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9952 - f1_Score: 0.9701
# done

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.09322603046894073
# Train Accuracy: 0.9703872203826904
# Train Precision: 0.9703872203826904
# Train Recall: 0.9703872203826904
# Train AUC: 0.9951521158218384
# Train F1_Score: 0.9700913429260254

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 35/35 [==============================] - 13s 369ms/step - loss: 0.6404 - accuracy: 0.7849 - precision: 0.7849 - recall: 0.7849 - auc: 0.8419 - f1_Score: 0.7834

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.6403663158416748
# Test Accuracy: 0.7849462628364563
# Test Precision: 0.7849462628364563
# Test Recall: 0.7849462628364563
# Test AUC: 0.8419249653816223
# Test F1_Score: 0.783409595489502

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#         fake       0.79      0.74      0.77       530
#         real       0.78      0.83      0.80       586
#
#     accuracy                           0.78      1116
#    macro avg       0.79      0.78      0.78      1116
# weighted avg       0.79      0.78      0.78      1116

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('EffectiveNetV2B3.csv', index = False)
