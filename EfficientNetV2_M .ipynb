# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adamax, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/train'
validation_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 175
IMG_HEIGHT = 175
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.1,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 2634 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : fake
# 1 : real

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2M Model**
#
#
# ### i. Create a EfficientNetV2M Model

# %%
base_model = tf.keras.applications.EfficientNetV2M(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(175,175,3),
                     include_preprocessing=True

                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 7s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-m (Functiona  (None, 6, 6, 1280)       53150388
#  l)
#
#  batch_normalization (BatchN  (None, 6, 6, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 53,979,702
# Trainable params: 53,681,270
# Non-trainable params: 298,432
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
early = tf.keras.callbacks.EarlyStopping( patience=10,
                                          min_delta=0.001,
                                          restore_best_weights=True)

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adamax(learning_rate=0.001)
sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=25,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=75,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/75
# 25/25 - 283s - loss: 0.7107 - accuracy: 0.5219 - precision: 0.5219 - recall: 0.5219 - auc: 0.5468 - f1_Score: 0.5212 - val_loss: 0.7081 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.4194 - val_f1_Score: 0.3118 - lr: 0.0010 - 283s/epoch - 11s/step
# Epoch 2/75
# 25/25 - 188s - loss: 0.6927 - accuracy: 0.5575 - precision: 0.5575 - recall: 0.5575 - auc: 0.5805 - f1_Score: 0.5451 - val_loss: 0.7512 - val_accuracy: 0.4531 - val_precision: 0.4531 - val_recall: 0.4531 - val_auc: 0.5413 - val_f1_Score: 0.3118 - lr: 0.0010 - 188s/epoch - 8s/step
# Epoch 3/75
# 25/25 - 145s - loss: 0.6670 - accuracy: 0.6175 - precision: 0.6175 - recall: 0.6175 - auc: 0.6639 - f1_Score: 0.6117 - val_loss: 0.6870 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.5760 - val_f1_Score: 0.4080 - lr: 0.0010 - 145s/epoch - 6s/step
# Epoch 4/75
# 25/25 - 95s - loss: 0.6314 - accuracy: 0.6414 - precision: 0.6414 - recall: 0.6414 - auc: 0.7010 - f1_Score: 0.6296 - val_loss: 0.7208 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.6290 - val_f1_Score: 0.5586 - lr: 0.0010 - 95s/epoch - 4s/step
# Epoch 5/75
# 25/25 - 89s - loss: 0.6309 - accuracy: 0.6662 - precision: 0.6662 - recall: 0.6662 - auc: 0.7224 - f1_Score: 0.6644 - val_loss: 0.5887 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7942 - val_f1_Score: 0.6946 - lr: 0.0010 - 89s/epoch - 4s/step
# Epoch 6/75
# 25/25 - 69s - loss: 0.5899 - accuracy: 0.6812 - precision: 0.6812 - recall: 0.6812 - auc: 0.7527 - f1_Score: 0.6745 - val_loss: 0.7669 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5652 - val_f1_Score: 0.4108 - lr: 0.0010 - 69s/epoch - 3s/step
# Epoch 7/75
# 25/25 - 56s - loss: 0.5560 - accuracy: 0.7138 - precision: 0.7138 - recall: 0.7138 - auc: 0.7892 - f1_Score: 0.7070 - val_loss: 0.7115 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6321 - val_f1_Score: 0.6015 - lr: 0.0010 - 56s/epoch - 2s/step
# Epoch 8/75
# 25/25 - 48s - loss: 0.5372 - accuracy: 0.7200 - precision: 0.7200 - recall: 0.7200 - auc: 0.8023 - f1_Score: 0.7162 - val_loss: 0.7056 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7184 - val_f1_Score: 0.6532 - lr: 0.0010 - 48s/epoch - 2s/step
# Epoch 9/75
# 25/25 - 44s - loss: 0.5182 - accuracy: 0.7525 - precision: 0.7525 - recall: 0.7525 - auc: 0.8273 - f1_Score: 0.7482 - val_loss: 0.7467 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.6403 - val_f1_Score: 0.5636 - lr: 0.0010 - 44s/epoch - 2s/step
# Epoch 10/75
# 25/25 - 42s - loss: 0.4980 - accuracy: 0.7825 - precision: 0.7825 - recall: 0.7825 - auc: 0.8434 - f1_Score: 0.7802 - val_loss: 1.1846 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5769 - val_f1_Score: 0.3263 - lr: 0.0010 - 42s/epoch - 2s/step
# Epoch 11/75
# 25/25 - 42s - loss: 0.4307 - accuracy: 0.8062 - precision: 0.8062 - recall: 0.8062 - auc: 0.8875 - f1_Score: 0.8061 - val_loss: 0.4174 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8948 - val_f1_Score: 0.7772 - lr: 3.1623e-04 - 42s/epoch - 2s/step
# Epoch 12/75
# 25/25 - 41s - loss: 0.3739 - accuracy: 0.8537 - precision: 0.8537 - recall: 0.8537 - auc: 0.9133 - f1_Score: 0.8531 - val_loss: 0.6871 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.7751 - val_f1_Score: 0.7312 - lr: 3.1623e-04 - 41s/epoch - 2s/step
# Epoch 13/75
# 25/25 - 38s - loss: 0.3197 - accuracy: 0.8676 - precision: 0.8676 - recall: 0.8676 - auc: 0.9372 - f1_Score: 0.8656 - val_loss: 0.5715 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.8264 - val_f1_Score: 0.7185 - lr: 3.1623e-04 - 38s/epoch - 2s/step
# Epoch 14/75
# 25/25 - 31s - loss: 0.3072 - accuracy: 0.8825 - precision: 0.8825 - recall: 0.8825 - auc: 0.9423 - f1_Score: 0.8815 - val_loss: 0.3990 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8982 - val_f1_Score: 0.8057 - lr: 3.1623e-04 - 31s/epoch - 1s/step
# Epoch 15/75
# 25/25 - 30s - loss: 0.2839 - accuracy: 0.8963 - precision: 0.8963 - recall: 0.8963 - auc: 0.9510 - f1_Score: 0.8945 - val_loss: 0.4636 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8730 - val_f1_Score: 0.8424 - lr: 3.1623e-04 - 30s/epoch - 1s/step
# Epoch 16/75
# 25/25 - 29s - loss: 0.2502 - accuracy: 0.9025 - precision: 0.9025 - recall: 0.9025 - auc: 0.9611 - f1_Score: 0.8996 - val_loss: 0.5250 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.8889 - val_f1_Score: 0.8487 - lr: 3.1623e-04 - 29s/epoch - 1s/step
# Epoch 17/75
# 25/25 - 29s - loss: 0.2229 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9699 - f1_Score: 0.9039 - val_loss: 0.4912 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8821 - val_f1_Score: 0.8181 - lr: 3.1623e-04 - 29s/epoch - 1s/step
# Epoch 18/75
# 25/25 - 26s - loss: 0.1993 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9751 - f1_Score: 0.9276 - val_loss: 0.5527 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8755 - val_f1_Score: 0.7851 - lr: 3.1623e-04 - 26s/epoch - 1s/step
# Epoch 19/75
# 25/25 - 28s - loss: 0.1803 - accuracy: 0.9312 - precision: 0.9312 - recall: 0.9312 - auc: 0.9782 - f1_Score: 0.9308 - val_loss: 0.7387 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.8291 - val_f1_Score: 0.7085 - lr: 3.1623e-04 - 28s/epoch - 1s/step
# Epoch 20/75
# 25/25 - 30s - loss: 0.1669 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9826 - f1_Score: 0.9331 - val_loss: 0.4719 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9023 - val_f1_Score: 0.8229 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 21/75
# 25/25 - 26s - loss: 0.1328 - accuracy: 0.9538 - precision: 0.9538 - recall: 0.9538 - auc: 0.9887 - f1_Score: 0.9532 - val_loss: 0.8418 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.8037 - val_f1_Score: 0.7031 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 22/75
# 25/25 - 28s - loss: 0.1365 - accuracy: 0.9513 - precision: 0.9513 - recall: 0.9513 - auc: 0.9883 - f1_Score: 0.9509 - val_loss: 0.6216 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.8511 - val_f1_Score: 0.7312 - lr: 1.0000e-04 - 28s/epoch - 1s/step
# Epoch 23/75
# 25/25 - 28s - loss: 0.1405 - accuracy: 0.9576 - precision: 0.9576 - recall: 0.9576 - auc: 0.9870 - f1_Score: 0.9571 - val_loss: 0.5869 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8716 - val_f1_Score: 0.7703 - lr: 1.0000e-04 - 28s/epoch - 1s/step
# Epoch 24/75
# 25/25 - 25s - loss: 0.1256 - accuracy: 0.9488 - precision: 0.9488 - recall: 0.9488 - auc: 0.9903 - f1_Score: 0.9482 - val_loss: 0.7287 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8481 - val_f1_Score: 0.7430 - lr: 1.0000e-04 - 25s/epoch - 996ms/step
# Epoch 25/75
# 25/25 - 23s - loss: 0.1012 - accuracy: 0.9638 - precision: 0.9638 - recall: 0.9638 - auc: 0.9942 - f1_Score: 0.9633 - val_loss: 0.4678 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9167 - val_f1_Score: 0.8565 - lr: 3.1623e-05 - 23s/epoch - 938ms/step
# Epoch 26/75
# 25/25 - 25s - loss: 0.1155 - accuracy: 0.9600 - precision: 0.9600 - recall: 0.9600 - auc: 0.9906 - f1_Score: 0.9595 - val_loss: 0.6192 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8911 - val_f1_Score: 0.7944 - lr: 3.1623e-05 - 25s/epoch - 981ms/step
# Epoch 27/75
# 25/25 - 23s - loss: 0.0849 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9961 - f1_Score: 0.9691 - val_loss: 0.5812 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.9065 - val_f1_Score: 0.7964 - lr: 3.1623e-05 - 23s/epoch - 914ms/step
# Epoch 28/75
# 25/25 - 26s - loss: 0.0945 - accuracy: 0.9638 - precision: 0.9638 - recall: 0.9638 - auc: 0.9943 - f1_Score: 0.9633 - val_loss: 0.5976 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8966 - val_f1_Score: 0.7813 - lr: 3.1623e-05 - 26s/epoch - 1s/step
# Epoch 29/75
# 25/25 - 24s - loss: 0.0857 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9938 - f1_Score: 0.9728 - val_loss: 0.4838 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9111 - val_f1_Score: 0.8413 - lr: 3.1623e-05 - 24s/epoch - 960ms/step
# Epoch 30/75
# 25/25 - 23s - loss: 0.1230 - accuracy: 0.9537 - precision: 0.9537 - recall: 0.9537 - auc: 0.9900 - f1_Score: 0.9530 - val_loss: 0.7274 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8604 - val_f1_Score: 0.7928 - lr: 1.0000e-05 - 23s/epoch - 927ms/step
# Epoch 31/75
# 25/25 - 22s - loss: 0.1004 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9935 - f1_Score: 0.9685 - val_loss: 0.6143 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8870 - val_f1_Score: 0.7851 - lr: 1.0000e-05 - 22s/epoch - 861ms/step
# Epoch 32/75
# 25/25 - 22s - loss: 0.0732 - accuracy: 0.9769 - precision: 0.9769 - recall: 0.9769 - auc: 0.9956 - f1_Score: 0.9765 - val_loss: 0.7756 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8438 - val_f1_Score: 0.7944 - lr: 1.0000e-05 - 22s/epoch - 896ms/step
# Epoch 33/75
# 25/25 - 21s - loss: 0.0759 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9964 - f1_Score: 0.9752 - val_loss: 0.4920 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9211 - val_f1_Score: 0.8565 - lr: 1.0000e-05 - 21s/epoch - 860ms/step
# Epoch 34/75
# 25/25 - 24s - loss: 0.0735 - accuracy: 0.9737 - precision: 0.9737 - recall: 0.9737 - auc: 0.9972 - f1_Score: 0.9735 - val_loss: 0.6619 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8872 - val_f1_Score: 0.7851 - lr: 1.0000e-05 - 24s/epoch - 973ms/step
# Epoch 35/75
# 25/25 - 22s - loss: 0.0779 - accuracy: 0.9743 - precision: 0.9743 - recall: 0.9743 - auc: 0.9960 - f1_Score: 0.9742 - val_loss: 0.6345 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8787 - val_f1_Score: 0.8031 - lr: 3.1623e-06 - 22s/epoch - 885ms/step
# Epoch 36/75
# 25/25 - 22s - loss: 0.0686 - accuracy: 0.9825 - precision: 0.9825 - recall: 0.9825 - auc: 0.9957 - f1_Score: 0.9824 - val_loss: 0.7677 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8618 - val_f1_Score: 0.7964 - lr: 3.1623e-06 - 22s/epoch - 885ms/step
# Epoch 37/75
# 25/25 - 22s - loss: 0.0958 - accuracy: 0.9640 - precision: 0.9640 - recall: 0.9640 - auc: 0.9945 - f1_Score: 0.9636 - val_loss: 0.4623 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9194 - val_f1_Score: 0.8565 - lr: 3.1623e-06 - 22s/epoch - 882ms/step
# Epoch 38/75
# 25/25 - 21s - loss: 0.0918 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9922 - f1_Score: 0.9702 - val_loss: 0.4242 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9397 - val_f1_Score: 0.8730 - lr: 3.1623e-06 - 21s/epoch - 844ms/step
# Epoch 39/75
# 25/25 - 22s - loss: 0.0725 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9971 - f1_Score: 0.9747 - val_loss: 0.5276 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9011 - val_f1_Score: 0.8247 - lr: 3.1623e-06 - 22s/epoch - 877ms/step
# Epoch 40/75
# 25/25 - 22s - loss: 0.0729 - accuracy: 0.9743 - precision: 0.9743 - recall: 0.9743 - auc: 0.9965 - f1_Score: 0.9736 - val_loss: 0.6272 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8997 - val_f1_Score: 0.8277 - lr: 1.0000e-06 - 22s/epoch - 864ms/step
# Epoch 41/75
# 25/25 - 22s - loss: 0.0642 - accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - auc: 0.9981 - f1_Score: 0.9799 - val_loss: 0.7808 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8718 - val_f1_Score: 0.7478 - lr: 1.0000e-06 - 22s/epoch - 864ms/step
# Epoch 42/75
# 25/25 - 23s - loss: 0.0897 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9949 - f1_Score: 0.9687 - val_loss: 0.8160 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8599 - val_f1_Score: 0.8031 - lr: 1.0000e-06 - 23s/epoch - 918ms/step
# Epoch 43/75
# 25/25 - 21s - loss: 0.0926 - accuracy: 0.9653 - precision: 0.9653 - recall: 0.9653 - auc: 0.9949 - f1_Score: 0.9650 - val_loss: 0.5907 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8967 - val_f1_Score: 0.8118 - lr: 1.0000e-06 - 21s/epoch - 843ms/step
# Epoch 44/75
# 25/25 - 21s - loss: 0.0642 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - auc: 0.9975 - f1_Score: 0.9779 - val_loss: 0.5809 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8857 - val_f1_Score: 0.8398 - lr: 1.0000e-06 - 21s/epoch - 856ms/step
# Epoch 45/75
# 25/25 - 22s - loss: 0.0754 - accuracy: 0.9787 - precision: 0.9787 - recall: 0.9787 - auc: 0.9959 - f1_Score: 0.9785 - val_loss: 0.6310 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.8599 - val_f1_Score: 0.8565 - lr: 3.1623e-07 - 22s/epoch - 891ms/step
# Epoch 46/75
# 25/25 - 24s - loss: 0.0875 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9952 - f1_Score: 0.9671 - val_loss: 0.5920 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9009 - val_f1_Score: 0.8000 - lr: 3.1623e-07 - 24s/epoch - 942ms/step
# Epoch 47/75
# 25/25 - 22s - loss: 0.0874 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9951 - f1_Score: 0.9668 - val_loss: 0.3039 - val_accuracy: 0.8906 - val_precision: 0.8906 - val_recall: 0.8906 - val_auc: 0.9607 - val_f1_Score: 0.8884 - lr: 3.1623e-07 - 22s/epoch - 864ms/step
# Epoch 48/75
# 25/25 - 21s - loss: 0.0932 - accuracy: 0.9717 - precision: 0.9717 - recall: 0.9717 - auc: 0.9936 - f1_Score: 0.9714 - val_loss: 0.8510 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.8450 - val_f1_Score: 0.7142 - lr: 3.1623e-07 - 21s/epoch - 860ms/step
# Epoch 49/75
# 25/25 - 21s - loss: 0.0791 - accuracy: 0.9762 - precision: 0.9762 - recall: 0.9762 - auc: 0.9960 - f1_Score: 0.9761 - val_loss: 0.4749 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9045 - val_f1_Score: 0.8565 - lr: 3.1623e-07 - 21s/epoch - 848ms/step
# Epoch 50/75
# 25/25 - 21s - loss: 0.0678 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9979 - f1_Score: 0.9728 - val_loss: 0.6660 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8936 - val_f1_Score: 0.7907 - lr: 3.1623e-07 - 21s/epoch - 828ms/step
# Epoch 51/75
# 25/25 - 21s - loss: 0.0677 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9976 - f1_Score: 0.9729 - val_loss: 0.4895 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9143 - val_f1_Score: 0.8281 - lr: 3.1623e-07 - 21s/epoch - 834ms/step
# Epoch 52/75
# 25/25 - 23s - loss: 0.0840 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9955 - f1_Score: 0.9699 - val_loss: 0.7660 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8634 - val_f1_Score: 0.7555 - lr: 3.1623e-07 - 23s/epoch - 926ms/step
# Epoch 53/75
# 25/25 - 21s - loss: 0.0614 - accuracy: 0.9833 - precision: 0.9833 - recall: 0.9833 - auc: 0.9979 - f1_Score: 0.9832 - val_loss: 0.5957 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9045 - val_f1_Score: 0.8551 - lr: 1.0000e-07 - 21s/epoch - 853ms/step
# Epoch 54/75
# 25/25 - 21s - loss: 0.0798 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9955 - f1_Score: 0.9771 - val_loss: 0.4284 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9263 - val_f1_Score: 0.8565 - lr: 1.0000e-07 - 21s/epoch - 845ms/step
# Epoch 55/75
# 25/25 - 21s - loss: 0.0797 - accuracy: 0.9692 - precision: 0.9692 - recall: 0.9692 - auc: 0.9951 - f1_Score: 0.9691 - val_loss: 0.5625 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8981 - val_f1_Score: 0.8260 - lr: 1.0000e-07 - 21s/epoch - 835ms/step
# Epoch 56/75
# 25/25 - 21s - loss: 0.0822 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9957 - f1_Score: 0.9695 - val_loss: 0.5398 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9067 - val_f1_Score: 0.8413 - lr: 1.0000e-07 - 21s/epoch - 846ms/step
# Epoch 57/75
# 25/25 - 21s - loss: 0.0569 - accuracy: 0.9825 - precision: 0.9825 - recall: 0.9825 - auc: 0.9982 - f1_Score: 0.9824 - val_loss: 0.8383 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.8530 - val_f1_Score: 0.6903 - lr: 1.0000e-07 - 21s/epoch - 846ms/step
# Epoch 58/75
# 25/25 - 21s - loss: 0.0664 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9976 - f1_Score: 0.9773 - val_loss: 0.7334 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8572 - val_f1_Score: 0.8118 - lr: 3.1623e-08 - 21s/epoch - 841ms/step
# Epoch 59/75
# 25/25 - 21s - loss: 0.0838 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9961 - f1_Score: 0.9670 - val_loss: 0.7112 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8909 - val_f1_Score: 0.8031 - lr: 3.1623e-08 - 21s/epoch - 840ms/step
# Epoch 60/75
# 25/25 - 21s - loss: 0.0845 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9955 - f1_Score: 0.9710 - val_loss: 0.4112 - val_accuracy: 0.8906 - val_precision: 0.8906 - val_recall: 0.8906 - val_auc: 0.9536 - val_f1_Score: 0.8900 - lr: 3.1623e-08 - 21s/epoch - 827ms/step
# Epoch 61/75
# 25/25 - 21s - loss: 0.0806 - accuracy: 0.9743 - precision: 0.9743 - recall: 0.9743 - auc: 0.9948 - f1_Score: 0.9740 - val_loss: 0.5976 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8936 - val_f1_Score: 0.8095 - lr: 3.1623e-08 - 21s/epoch - 829ms/step
# Epoch 62/75
# 25/25 - 21s - loss: 0.0910 - accuracy: 0.9640 - precision: 0.9640 - recall: 0.9640 - auc: 0.9940 - f1_Score: 0.9635 - val_loss: 0.5999 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8987 - val_f1_Score: 0.7804 - lr: 3.1623e-08 - 21s/epoch - 844ms/step
# Epoch 63/75
# 25/25 - 21s - loss: 0.0593 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9984 - f1_Score: 0.9772 - val_loss: 0.4365 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9258 - val_f1_Score: 0.8277 - lr: 1.0000e-08 - 21s/epoch - 857ms/step
# Epoch 64/75
# 25/25 - 21s - loss: 0.1004 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9915 - f1_Score: 0.9684 - val_loss: 0.8135 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8550 - val_f1_Score: 0.7430 - lr: 1.0000e-08 - 21s/epoch - 849ms/step
# Epoch 65/75
# 25/25 - 21s - loss: 0.0746 - accuracy: 0.9762 - precision: 0.9762 - recall: 0.9762 - auc: 0.9958 - f1_Score: 0.9760 - val_loss: 0.7546 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8618 - val_f1_Score: 0.8000 - lr: 1.0000e-08 - 21s/epoch - 827ms/step
# Epoch 66/75
# 25/25 - 21s - loss: 0.0900 - accuracy: 0.9575 - precision: 0.9575 - recall: 0.9575 - auc: 0.9944 - f1_Score: 0.9573 - val_loss: 0.8886 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8262 - val_f1_Score: 0.7490 - lr: 1.0000e-08 - 21s/epoch - 835ms/step
# Epoch 67/75
# 25/25 - 21s - loss: 0.0910 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9947 - f1_Score: 0.9686 - val_loss: 0.3960 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9426 - val_f1_Score: 0.8533 - lr: 1.0000e-08 - 21s/epoch - 836ms/step
# Epoch 68/75
# 25/25 - 21s - loss: 0.0761 - accuracy: 0.9737 - precision: 0.9737 - recall: 0.9737 - auc: 0.9961 - f1_Score: 0.9734 - val_loss: 0.7122 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8757 - val_f1_Score: 0.8118 - lr: 3.1623e-09 - 21s/epoch - 846ms/step
# Epoch 69/75
# 25/25 - 21s - loss: 0.0760 - accuracy: 0.9762 - precision: 0.9762 - recall: 0.9762 - auc: 0.9955 - f1_Score: 0.9760 - val_loss: 0.6569 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8735 - val_f1_Score: 0.7793 - lr: 3.1623e-09 - 21s/epoch - 838ms/step
# Epoch 70/75
# 25/25 - 21s - loss: 0.0680 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9955 - f1_Score: 0.9811 - val_loss: 0.6481 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8767 - val_f1_Score: 0.7968 - lr: 3.1623e-09 - 21s/epoch - 827ms/step
# Epoch 71/75
# 25/25 - 23s - loss: 0.0566 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9986 - f1_Score: 0.9772 - val_loss: 0.5623 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9050 - val_f1_Score: 0.8078 - lr: 3.1623e-09 - 23s/epoch - 901ms/step
# Epoch 72/75
# 25/25 - 21s - loss: 0.0710 - accuracy: 0.9787 - precision: 0.9787 - recall: 0.9787 - auc: 0.9960 - f1_Score: 0.9786 - val_loss: 0.5593 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9139 - val_f1_Score: 0.8260 - lr: 3.1623e-09 - 21s/epoch - 840ms/step
# Epoch 73/75
# 25/25 - 21s - loss: 0.0700 - accuracy: 0.9762 - precision: 0.9762 - recall: 0.9762 - auc: 0.9969 - f1_Score: 0.9758 - val_loss: 0.7408 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8816 - val_f1_Score: 0.7793 - lr: 1.0000e-09 - 21s/epoch - 820ms/step
# Epoch 74/75
# 25/25 - 20s - loss: 0.0760 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9969 - f1_Score: 0.9709 - val_loss: 0.3809 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9473 - val_f1_Score: 0.8719 - lr: 1.0000e-09 - 20s/epoch - 817ms/step
# Epoch 75/75
# 25/25 - 21s - loss: 0.0860 - accuracy: 0.9675 - precision: 0.9675 - recall: 0.9675 - auc: 0.9957 - f1_Score: 0.9671 - val_loss: 0.7231 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8604 - val_f1_Score: 0.7793 - lr: 1.0000e-09 - 21s/epoch - 835ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']
learning_rate = history.history['lr']
print("Train Accuracy:" ,train_accuracy)
print("val Accuracy:" ,val_accuracy)
print("Train Loss:" ,train_loss)
print("val Loss:" ,val_loss)
# Out:
# Train Accuracy: [0.5218508839607239, 0.5575000047683716, 0.6175000071525574, 0.6413881778717041, 0.6662499904632568, 0.6812499761581421, 0.7137500047683716, 0.7200000286102295, 0.7524999976158142, 0.7825000286102295, 0.8062499761581421, 0.8537499904632568, 0.8676092624664307, 0.8824999928474426, 0.8962500095367432, 0.9024999737739563, 0.9049999713897705, 0.9280205368995667, 0.9312499761581421, 0.9337499737739563, 0.9537500143051147, 0.9512500166893005, 0.9575835466384888, 0.9487500190734863, 0.9637500047683716, 0.9599999785423279, 0.9700000286102295, 0.9637500047683716, 0.9730077385902405, 0.9537274837493896, 0.96875, 0.9768637418746948, 0.9755784273147583, 0.9737499952316284, 0.974293053150177, 0.9825000166893005, 0.9640102982521057, 0.9704369902610779, 0.9750000238418579, 0.974293053150177, 0.9800000190734863, 0.96875, 0.9652956128120422, 0.9781491160392761, 0.9787499904632568, 0.9674999713897705, 0.9674999713897705, 0.9717223644256592, 0.9762499928474426, 0.9730077385902405, 0.9730077385902405, 0.9700000286102295, 0.9832904934883118, 0.9775000214576721, 0.9691516757011414, 0.9700000286102295, 0.9825000166893005, 0.9775000214576721, 0.9674999713897705, 0.9712499976158142, 0.974293053150177, 0.9640102982521057, 0.9775000214576721, 0.96875, 0.9762499928474426, 0.9574999809265137, 0.96875, 0.9737499952316284, 0.9762499928474426, 0.981249988079071, 0.9775000214576721, 0.9787499904632568, 0.9762499928474426, 0.9712499976158142, 0.9674999713897705]
# val Accuracy: [0.453125, 0.453125, 0.546875, 0.5625, 0.71875, 0.515625, 0.609375, 0.65625, 0.625, 0.484375, 0.796875, 0.734375, 0.71875, 0.8125, 0.84375, 0.859375, 0.828125, 0.796875, 0.71875, 0.828125, 0.703125, 0.734375, 0.78125, 0.765625, 0.859375, 0.796875, 0.796875, 0.78125, 0.84375, 0.796875, 0.796875, 0.796875, 0.859375, 0.796875, 0.8125, 0.796875, 0.859375, 0.875, 0.828125, 0.828125, 0.765625, 0.8125, 0.8125, 0.84375, 0.859375, 0.8125, 0.890625, 0.734375, 0.859375, 0.796875, 0.828125, 0.765625, 0.859375, 0.859375, 0.828125, 0.84375, 0.703125, 0.8125, 0.8125, 0.890625, 0.8125, 0.78125, 0.828125, 0.765625, 0.8125, 0.75, 0.859375, 0.8125, 0.78125, 0.796875, 0.8125, 0.828125, 0.78125, 0.875, 0.78125]
# Train Loss: [0.7107149958610535, 0.6926847100257874, 0.6670393347740173, 0.6314034461975098, 0.630861759185791, 0.5899037718772888, 0.5559776425361633, 0.5371692776679993, 0.5181947946548462, 0.4979740083217621, 0.43067896366119385, 0.37387368083000183, 0.319720983505249, 0.30721110105514526, 0.2838584780693054, 0.2501774728298187, 0.22293880581855774, 0.19926749169826508, 0.18030467629432678, 0.16692639887332916, 0.13280639052391052, 0.1365211457014084, 0.14047883450984955, 0.12556692957878113, 0.10120917111635208, 0.11546193808317184, 0.08494388312101364, 0.0945422425866127, 0.08573410660028458, 0.12296083569526672, 0.10044212639331818, 0.07319276034832001, 0.07588151097297668, 0.07354842871427536, 0.07794061303138733, 0.0686035305261612, 0.09579294174909592, 0.09184684604406357, 0.07246138155460358, 0.07285211235284805, 0.06416088342666626, 0.08968840539455414, 0.0925757959485054, 0.06420599669218063, 0.07542528957128525, 0.08746170997619629, 0.08744008094072342, 0.09323301166296005, 0.07905881106853485, 0.06775480508804321, 0.06773404777050018, 0.08396411687135696, 0.06144800782203674, 0.07984916865825653, 0.07967645674943924, 0.08221600204706192, 0.05693089962005615, 0.06641893088817596, 0.08376054465770721, 0.08448485285043716, 0.08057266473770142, 0.09102475643157959, 0.05926700681447983, 0.10040978342294693, 0.0746038556098938, 0.08998758345842361, 0.0910421833395958, 0.0760997086763382, 0.07603663951158524, 0.06797222048044205, 0.0565970242023468, 0.0709577277302742, 0.07004223018884659, 0.07600793987512589, 0.08595822006464005]
# val Loss: [0.7080625295639038, 0.7511516809463501, 0.6869741678237915, 0.7208120822906494, 0.588654100894928, 0.7669391632080078, 0.7114526033401489, 0.7055782675743103, 0.7467441558837891, 1.1846165657043457, 0.4174487888813019, 0.6871441602706909, 0.5714504718780518, 0.39899760484695435, 0.463612824678421, 0.5249646902084351, 0.49120140075683594, 0.552742600440979, 0.738673210144043, 0.4718514084815979, 0.8418055176734924, 0.621550440788269, 0.5869385600090027, 0.728667676448822, 0.4678193926811218, 0.61916184425354, 0.5812157392501831, 0.5975940227508545, 0.48378342390060425, 0.7274152040481567, 0.614264965057373, 0.7755892276763916, 0.4919922351837158, 0.661884069442749, 0.6344668865203857, 0.7677428722381592, 0.46234869956970215, 0.4242393374443054, 0.5275875329971313, 0.627168595790863, 0.7808356881141663, 0.8159544467926025, 0.5907452702522278, 0.5809329748153687, 0.6310268044471741, 0.5920442938804626, 0.30393195152282715, 0.8510015606880188, 0.474899023771286, 0.6659602522850037, 0.48945772647857666, 0.7659532427787781, 0.595723032951355, 0.4284169375896454, 0.5624842643737793, 0.5398044586181641, 0.838329553604126, 0.7334065437316895, 0.7111555337905884, 0.41122186183929443, 0.597599983215332, 0.5998558402061462, 0.43650370836257935, 0.8135095834732056, 0.7546234130859375, 0.8885883092880249, 0.3959714472293854, 0.7121791839599609, 0.6568715572357178, 0.6480701565742493, 0.5623395442962646, 0.5593087673187256, 0.7407686710357666, 0.3809267580509186, 0.72308349609375]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 35/35 [==============================] - 26s 629ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 83/83 [==============================] - 58s 702ms/step - loss: 0.0323 - accuracy: 0.9886 - precision: 0.9886 - recall: 0.9886 - auc: 0.9996 - f1_Score: 0.9885

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.032332275062799454
# Train Accuracy: 0.9886105060577393
# Train Precision: 0.9886105060577393
# Train Recall: 0.9886105060577393
# Train AUC: 0.9995827078819275
# Train F1_Score: 0.9885052442550659

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 35/35 [==============================] - 14s 408ms/step - loss: 0.5693 - accuracy: 0.8217 - precision: 0.8217 - recall: 0.8217 - auc: 0.8991 - f1_Score: 0.8199

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.5693463087081909
# Test Accuracy: 0.8216845989227295
# Test Precision: 0.8216845989227295
# Test Recall: 0.8216845989227295
# Test AUC: 0.899108350276947
# Test F1_Score: 0.8199029564857483

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#         fake       0.85      0.76      0.80       530
#         real       0.80      0.88      0.84       586
#
#     accuracy                           0.82      1116
#    macro avg       0.83      0.82      0.82      1116
# weighted avg       0.82      0.82      0.82      1116

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('EffectiveNetV2M.csv', index = False)
