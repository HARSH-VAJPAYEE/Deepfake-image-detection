# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/train'
validation_dataset_path = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 175
IMG_HEIGHT = 175
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.1,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 2634 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : fake
# 1 : real

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2S Model**
#
#
# ### i. Create a EfficientNetV2S Model

# %%
base_model = tf.keras.applications.EfficientNetV2S(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(175,175,3),
                     include_preprocessing=True

                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 [==============================] - 1s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-s (Functiona  (None, 6, 6, 1280)       20331360
#  l)
#
#  batch_normalization (BatchN  (None, 6, 6, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 21,160,674
# Trainable params: 21,000,402
# Non-trainable params: 160,272
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
early = tf.keras.callbacks.EarlyStopping( patience=10,
                                          min_delta=0.001,
                                          restore_best_weights=True)

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)
sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=25,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=75,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/75
# 25/25 - 170s - loss: 0.7363 - accuracy: 0.5038 - precision: 0.5038 - recall: 0.5038 - auc: 0.5161 - f1_Score: 0.4944 - val_loss: 0.6900 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5859 - val_f1_Score: 0.3402 - lr: 0.0010 - 170s/epoch - 7s/step
# Epoch 2/75
# 25/25 - 100s - loss: 0.7097 - accuracy: 0.5038 - precision: 0.5038 - recall: 0.5038 - auc: 0.5225 - f1_Score: 0.4763 - val_loss: 0.6605 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6204 - val_f1_Score: 0.4805 - lr: 0.0010 - 100s/epoch - 4s/step
# Epoch 3/75
# 25/25 - 77s - loss: 0.6888 - accuracy: 0.5750 - precision: 0.5750 - recall: 0.5750 - auc: 0.5986 - f1_Score: 0.5573 - val_loss: 0.7049 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5409 - val_f1_Score: 0.5195 - lr: 0.0010 - 77s/epoch - 3s/step
# Epoch 4/75
# 25/25 - 61s - loss: 0.6662 - accuracy: 0.5975 - precision: 0.5975 - recall: 0.5975 - auc: 0.6323 - f1_Score: 0.5934 - val_loss: 0.7286 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6018 - val_f1_Score: 0.5312 - lr: 0.0010 - 61s/epoch - 2s/step
# Epoch 5/75
# 25/25 - 52s - loss: 0.6772 - accuracy: 0.6363 - precision: 0.6363 - recall: 0.6363 - auc: 0.6467 - f1_Score: 0.6341 - val_loss: 0.6703 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6614 - val_f1_Score: 0.4896 - lr: 0.0010 - 52s/epoch - 2s/step
# Epoch 6/75
# 25/25 - 47s - loss: 0.6423 - accuracy: 0.6538 - precision: 0.6538 - recall: 0.6538 - auc: 0.6950 - f1_Score: 0.6477 - val_loss: 0.9689 - val_accuracy: 0.5469 - val_precision: 0.5469 - val_recall: 0.5469 - val_auc: 0.5920 - val_f1_Score: 0.3535 - lr: 0.0010 - 47s/epoch - 2s/step
# Epoch 7/75
# 25/25 - 37s - loss: 0.6240 - accuracy: 0.6600 - precision: 0.6600 - recall: 0.6600 - auc: 0.7189 - f1_Score: 0.6502 - val_loss: 0.7468 - val_accuracy: 0.5781 - val_precision: 0.5781 - val_recall: 0.5781 - val_auc: 0.6562 - val_f1_Score: 0.3981 - lr: 0.0010 - 37s/epoch - 1s/step
# Epoch 8/75
# 25/25 - 36s - loss: 0.6163 - accuracy: 0.6722 - precision: 0.6722 - recall: 0.6722 - auc: 0.7285 - f1_Score: 0.6617 - val_loss: 0.8056 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.6213 - val_f1_Score: 0.3600 - lr: 3.1623e-04 - 36s/epoch - 1s/step
# Epoch 9/75
# 25/25 - 30s - loss: 0.5552 - accuracy: 0.7212 - precision: 0.7212 - recall: 0.7212 - auc: 0.7908 - f1_Score: 0.7178 - val_loss: 0.5456 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8101 - val_f1_Score: 0.7651 - lr: 3.1623e-04 - 30s/epoch - 1s/step
# Epoch 10/75
# 25/25 - 30s - loss: 0.5406 - accuracy: 0.7400 - precision: 0.7400 - recall: 0.7400 - auc: 0.8074 - f1_Score: 0.7387 - val_loss: 0.5781 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7817 - val_f1_Score: 0.7163 - lr: 3.1623e-04 - 30s/epoch - 1s/step
# Epoch 11/75
# 25/25 - 27s - loss: 0.5214 - accuracy: 0.7648 - precision: 0.7648 - recall: 0.7648 - auc: 0.8214 - f1_Score: 0.7619 - val_loss: 0.6483 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.7244 - val_f1_Score: 0.5926 - lr: 3.1623e-04 - 27s/epoch - 1s/step
# Epoch 12/75
# 25/25 - 25s - loss: 0.4301 - accuracy: 0.8125 - precision: 0.8125 - recall: 0.8125 - auc: 0.8847 - f1_Score: 0.8101 - val_loss: 1.4398 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.5437 - val_f1_Score: 0.3600 - lr: 3.1623e-04 - 25s/epoch - 1s/step
# Epoch 13/75
# 25/25 - 24s - loss: 0.4291 - accuracy: 0.8252 - precision: 0.8252 - recall: 0.8252 - auc: 0.8853 - f1_Score: 0.8234 - val_loss: 0.7490 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7349 - val_f1_Score: 0.6008 - lr: 3.1623e-04 - 24s/epoch - 973ms/step
# Epoch 14/75
# 25/25 - 27s - loss: 0.3901 - accuracy: 0.8225 - precision: 0.8225 - recall: 0.8225 - auc: 0.9056 - f1_Score: 0.8196 - val_loss: 2.1806 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5339 - val_f1_Score: 0.3263 - lr: 3.1623e-04 - 27s/epoch - 1s/step
# Epoch 15/75
# 25/25 - 23s - loss: 0.3626 - accuracy: 0.8509 - precision: 0.8509 - recall: 0.8509 - auc: 0.9198 - f1_Score: 0.8498 - val_loss: 0.5797 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.7996 - val_f1_Score: 0.7031 - lr: 1.0000e-04 - 23s/epoch - 907ms/step
# Epoch 16/75
# 25/25 - 25s - loss: 0.2819 - accuracy: 0.8950 - precision: 0.8950 - recall: 0.8950 - auc: 0.9521 - f1_Score: 0.8938 - val_loss: 0.7376 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7642 - val_f1_Score: 0.6718 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 17/75
# 25/25 - 23s - loss: 0.2541 - accuracy: 0.9000 - precision: 0.9000 - recall: 0.9000 - auc: 0.9605 - f1_Score: 0.8990 - val_loss: 0.6054 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8420 - val_f1_Score: 0.8123 - lr: 1.0000e-04 - 23s/epoch - 930ms/step
# Epoch 18/75
# 25/25 - 24s - loss: 0.1959 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9780 - f1_Score: 0.9179 - val_loss: 0.6651 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8394 - val_f1_Score: 0.7703 - lr: 1.0000e-04 - 24s/epoch - 947ms/step
# Epoch 19/75
# 25/25 - 21s - loss: 0.2346 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9651 - f1_Score: 0.9117 - val_loss: 0.7541 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8105 - val_f1_Score: 0.7793 - lr: 1.0000e-04 - 21s/epoch - 831ms/step
# Epoch 20/75
# 25/25 - 24s - loss: 0.1978 - accuracy: 0.9300 - precision: 0.9300 - recall: 0.9300 - auc: 0.9763 - f1_Score: 0.9291 - val_loss: 0.6222 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8547 - val_f1_Score: 0.7460 - lr: 3.1623e-05 - 24s/epoch - 943ms/step
# Epoch 21/75
# 25/25 - 23s - loss: 0.1778 - accuracy: 0.9362 - precision: 0.9362 - recall: 0.9362 - auc: 0.9799 - f1_Score: 0.9355 - val_loss: 0.7417 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8186 - val_f1_Score: 0.7585 - lr: 3.1623e-05 - 23s/epoch - 901ms/step
# Epoch 22/75
# 25/25 - 22s - loss: 0.1621 - accuracy: 0.9375 - precision: 0.9375 - recall: 0.9375 - auc: 0.9849 - f1_Score: 0.9373 - val_loss: 0.6841 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.8318 - val_f1_Score: 0.7290 - lr: 3.1623e-05 - 22s/epoch - 868ms/step
# Epoch 23/75
# 25/25 - 20s - loss: 0.1463 - accuracy: 0.9450 - precision: 0.9450 - recall: 0.9450 - auc: 0.9870 - f1_Score: 0.9442 - val_loss: 0.3414 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9409 - val_f1_Score: 0.8438 - lr: 3.1623e-05 - 20s/epoch - 820ms/step
# Epoch 24/75
# 25/25 - 21s - loss: 0.1551 - accuracy: 0.9463 - precision: 0.9463 - recall: 0.9463 - auc: 0.9858 - f1_Score: 0.9460 - val_loss: 0.8510 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7961 - val_f1_Score: 0.7188 - lr: 3.1623e-05 - 21s/epoch - 823ms/step
# Epoch 25/75
# 25/25 - 18s - loss: 0.1217 - accuracy: 0.9538 - precision: 0.9538 - recall: 0.9538 - auc: 0.9912 - f1_Score: 0.9532 - val_loss: 0.9565 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.7966 - val_f1_Score: 0.6995 - lr: 3.1623e-05 - 18s/epoch - 724ms/step
# Epoch 26/75
# 25/25 - 19s - loss: 0.1508 - accuracy: 0.9488 - precision: 0.9488 - recall: 0.9488 - auc: 0.9849 - f1_Score: 0.9476 - val_loss: 0.5807 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8923 - val_f1_Score: 0.8000 - lr: 3.1623e-05 - 19s/epoch - 774ms/step
# Epoch 27/75
# 25/25 - 19s - loss: 0.1478 - accuracy: 0.9475 - precision: 0.9475 - recall: 0.9475 - auc: 0.9861 - f1_Score: 0.9471 - val_loss: 0.8715 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.8169 - val_f1_Score: 0.6995 - lr: 3.1623e-05 - 19s/epoch - 769ms/step
# Epoch 28/75
# 25/25 - 18s - loss: 0.0974 - accuracy: 0.9640 - precision: 0.9640 - recall: 0.9640 - auc: 0.9944 - f1_Score: 0.9637 - val_loss: 0.4222 - val_accuracy: 0.8906 - val_precision: 0.8906 - val_recall: 0.8906 - val_auc: 0.9265 - val_f1_Score: 0.8843 - lr: 3.1623e-05 - 18s/epoch - 722ms/step
# Epoch 29/75
# 25/25 - 20s - loss: 0.1285 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9890 - f1_Score: 0.9547 - val_loss: 0.8458 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8291 - val_f1_Score: 0.7815 - lr: 1.0000e-05 - 20s/epoch - 782ms/step
# Epoch 30/75
# 25/25 - 19s - loss: 0.1212 - accuracy: 0.9588 - precision: 0.9588 - recall: 0.9588 - auc: 0.9894 - f1_Score: 0.9581 - val_loss: 0.7319 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8572 - val_f1_Score: 0.7810 - lr: 1.0000e-05 - 19s/epoch - 745ms/step
# Epoch 31/75
# 25/25 - 19s - loss: 0.1350 - accuracy: 0.9460 - precision: 0.9460 - recall: 0.9460 - auc: 0.9882 - f1_Score: 0.9453 - val_loss: 1.1457 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.7720 - val_f1_Score: 0.7025 - lr: 1.0000e-05 - 19s/epoch - 768ms/step
# Epoch 32/75
# 25/25 - 18s - loss: 0.1035 - accuracy: 0.9625 - precision: 0.9625 - recall: 0.9625 - auc: 0.9936 - f1_Score: 0.9618 - val_loss: 0.7392 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8608 - val_f1_Score: 0.8118 - lr: 1.0000e-05 - 18s/epoch - 739ms/step
# Epoch 33/75
# 25/25 - 18s - loss: 0.1051 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9913 - f1_Score: 0.9583 - val_loss: 0.6850 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8562 - val_f1_Score: 0.7907 - lr: 1.0000e-05 - 18s/epoch - 726ms/step
# Epoch 34/75
# 25/25 - 19s - loss: 0.1056 - accuracy: 0.9575 - precision: 0.9575 - recall: 0.9575 - auc: 0.9933 - f1_Score: 0.9568 - val_loss: 0.5335 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.9087 - val_f1_Score: 0.7968 - lr: 3.1623e-06 - 19s/epoch - 743ms/step
# Epoch 35/75
# 25/25 - 18s - loss: 0.1157 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9904 - f1_Score: 0.9556 - val_loss: 0.7157 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8425 - val_f1_Score: 0.7478 - lr: 3.1623e-06 - 18s/epoch - 730ms/step
# Epoch 36/75
# 25/25 - 18s - loss: 0.1276 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - auc: 0.9903 - f1_Score: 0.9519 - val_loss: 0.7906 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8301 - val_f1_Score: 0.7625 - lr: 3.1623e-06 - 18s/epoch - 724ms/step
# Epoch 37/75
# 25/25 - 18s - loss: 0.1181 - accuracy: 0.9640 - precision: 0.9640 - recall: 0.9640 - auc: 0.9890 - f1_Score: 0.9638 - val_loss: 0.6285 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8860 - val_f1_Score: 0.8108 - lr: 3.1623e-06 - 18s/epoch - 713ms/step
# Epoch 38/75
# 25/25 - 17s - loss: 0.1177 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9907 - f1_Score: 0.9563 - val_loss: 0.7471 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8728 - val_f1_Score: 0.7668 - lr: 3.1623e-06 - 17s/epoch - 699ms/step
# Epoch 39/75
# 25/25 - 18s - loss: 0.1063 - accuracy: 0.9638 - precision: 0.9638 - recall: 0.9638 - auc: 0.9916 - f1_Score: 0.9633 - val_loss: 0.5480 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9019 - val_f1_Score: 0.8277 - lr: 1.0000e-06 - 18s/epoch - 706ms/step
# Epoch 40/75
# 25/25 - 18s - loss: 0.1180 - accuracy: 0.9576 - precision: 0.9576 - recall: 0.9576 - auc: 0.9905 - f1_Score: 0.9573 - val_loss: 0.4980 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9131 - val_f1_Score: 0.8303 - lr: 1.0000e-06 - 18s/epoch - 709ms/step
# Epoch 41/75
# 25/25 - 18s - loss: 0.1030 - accuracy: 0.9537 - precision: 0.9537 - recall: 0.9537 - auc: 0.9943 - f1_Score: 0.9532 - val_loss: 0.5031 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9182 - val_f1_Score: 0.8095 - lr: 1.0000e-06 - 18s/epoch - 714ms/step
# Epoch 42/75
# 25/25 - 18s - loss: 0.0775 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9969 - f1_Score: 0.9748 - val_loss: 0.7968 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8384 - val_f1_Score: 0.7430 - lr: 1.0000e-06 - 18s/epoch - 701ms/step
# Epoch 43/75
# 25/25 - 17s - loss: 0.1236 - accuracy: 0.9588 - precision: 0.9588 - recall: 0.9588 - auc: 0.9892 - f1_Score: 0.9584 - val_loss: 0.6296 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8977 - val_f1_Score: 0.8281 - lr: 1.0000e-06 - 17s/epoch - 697ms/step
# Epoch 44/75
# 25/25 - 18s - loss: 0.1084 - accuracy: 0.9613 - precision: 0.9613 - recall: 0.9613 - auc: 0.9922 - f1_Score: 0.9611 - val_loss: 0.9676 - val_accuracy: 0.7031 - val_precision: 0.7031 - val_recall: 0.7031 - val_auc: 0.8003 - val_f1_Score: 0.6971 - lr: 3.1623e-07 - 18s/epoch - 729ms/step
# Epoch 45/75
# 25/25 - 18s - loss: 0.0930 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9950 - f1_Score: 0.9646 - val_loss: 0.5184 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9084 - val_f1_Score: 0.8271 - lr: 3.1623e-07 - 18s/epoch - 715ms/step
# Epoch 46/75
# 25/25 - 18s - loss: 0.0871 - accuracy: 0.9725 - precision: 0.9725 - recall: 0.9725 - auc: 0.9954 - f1_Score: 0.9723 - val_loss: 0.7056 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8735 - val_f1_Score: 0.8303 - lr: 3.1623e-07 - 18s/epoch - 724ms/step
# Epoch 47/75
# 25/25 - 18s - loss: 0.1141 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9914 - f1_Score: 0.9586 - val_loss: 1.0549 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7854 - val_f1_Score: 0.7143 - lr: 3.1623e-07 - 18s/epoch - 711ms/step
# Epoch 48/75
# 25/25 - 17s - loss: 0.1204 - accuracy: 0.9524 - precision: 0.9524 - recall: 0.9524 - auc: 0.9905 - f1_Score: 0.9520 - val_loss: 0.5093 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.9089 - val_f1_Score: 0.7603 - lr: 3.1623e-07 - 17s/epoch - 675ms/step
# Epoch 49/75
# 25/25 - 17s - loss: 0.0990 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9941 - f1_Score: 0.9648 - val_loss: 0.3489 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9446 - val_f1_Score: 0.9048 - lr: 1.0000e-07 - 17s/epoch - 695ms/step
# Epoch 50/75
# 25/25 - 17s - loss: 0.1287 - accuracy: 0.9538 - precision: 0.9538 - recall: 0.9538 - auc: 0.9882 - f1_Score: 0.9537 - val_loss: 0.8071 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.8455 - val_f1_Score: 0.7143 - lr: 1.0000e-07 - 17s/epoch - 699ms/step
# Epoch 51/75
# 25/25 - 17s - loss: 0.0928 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9940 - f1_Score: 0.9696 - val_loss: 0.5048 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.9070 - val_f1_Score: 0.7907 - lr: 1.0000e-07 - 17s/epoch - 686ms/step
# Epoch 52/75
# 25/25 - 18s - loss: 0.1286 - accuracy: 0.9575 - precision: 0.9575 - recall: 0.9575 - auc: 0.9873 - f1_Score: 0.9572 - val_loss: 0.8548 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8181 - val_f1_Score: 0.7165 - lr: 1.0000e-07 - 18s/epoch - 703ms/step
# Epoch 53/75
# 25/25 - 18s - loss: 0.1070 - accuracy: 0.9613 - precision: 0.9613 - recall: 0.9613 - auc: 0.9927 - f1_Score: 0.9609 - val_loss: 0.5456 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9001 - val_f1_Score: 0.8359 - lr: 1.0000e-07 - 18s/epoch - 714ms/step
# Epoch 54/75
# 25/25 - 17s - loss: 0.1001 - accuracy: 0.9614 - precision: 0.9614 - recall: 0.9614 - auc: 0.9930 - f1_Score: 0.9608 - val_loss: 0.6614 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8684 - val_f1_Score: 0.7585 - lr: 3.1623e-08 - 17s/epoch - 692ms/step
# Epoch 55/75
# 25/25 - 17s - loss: 0.1092 - accuracy: 0.9588 - precision: 0.9588 - recall: 0.9588 - auc: 0.9922 - f1_Score: 0.9582 - val_loss: 0.7524 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8625 - val_f1_Score: 0.8095 - lr: 3.1623e-08 - 17s/epoch - 691ms/step
# Epoch 56/75
# 25/25 - 17s - loss: 0.0890 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9946 - f1_Score: 0.9712 - val_loss: 0.6337 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8745 - val_f1_Score: 0.8229 - lr: 3.1623e-08 - 17s/epoch - 697ms/step
# Epoch 57/75
# 25/25 - 17s - loss: 0.1081 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9925 - f1_Score: 0.9558 - val_loss: 1.1948 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.7214 - val_f1_Score: 0.6653 - lr: 3.1623e-08 - 17s/epoch - 673ms/step
# Epoch 58/75
# 25/25 - 17s - loss: 0.1071 - accuracy: 0.9588 - precision: 0.9588 - recall: 0.9588 - auc: 0.9930 - f1_Score: 0.9585 - val_loss: 0.7627 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8420 - val_f1_Score: 0.8108 - lr: 3.1623e-08 - 17s/epoch - 687ms/step
# Epoch 59/75
# 25/25 - 17s - loss: 0.1187 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9906 - f1_Score: 0.9552 - val_loss: 0.4264 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9448 - val_f1_Score: 0.8436 - lr: 1.0000e-08 - 17s/epoch - 696ms/step
# Epoch 60/75
# 25/25 - 17s - loss: 0.0831 - accuracy: 0.9725 - precision: 0.9725 - recall: 0.9725 - auc: 0.9964 - f1_Score: 0.9723 - val_loss: 0.9533 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8293 - val_f1_Score: 0.7460 - lr: 1.0000e-08 - 17s/epoch - 683ms/step
# Epoch 61/75
# 25/25 - 17s - loss: 0.0977 - accuracy: 0.9743 - precision: 0.9743 - recall: 0.9743 - auc: 0.9922 - f1_Score: 0.9739 - val_loss: 0.8378 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.8333 - val_f1_Score: 0.7327 - lr: 1.0000e-08 - 17s/epoch - 679ms/step
# Epoch 62/75
# 25/25 - 17s - loss: 0.1220 - accuracy: 0.9613 - precision: 0.9613 - recall: 0.9613 - auc: 0.9899 - f1_Score: 0.9609 - val_loss: 1.2817 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7345 - val_f1_Score: 0.7185 - lr: 1.0000e-08 - 17s/epoch - 687ms/step
# Epoch 63/75
# 25/25 - 18s - loss: 0.0980 - accuracy: 0.9650 - precision: 0.9650 - recall: 0.9650 - auc: 0.9941 - f1_Score: 0.9643 - val_loss: 0.6183 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8818 - val_f1_Score: 0.8281 - lr: 1.0000e-08 - 18s/epoch - 705ms/step
# Epoch 64/75
# 25/25 - 17s - loss: 0.1109 - accuracy: 0.9640 - precision: 0.9640 - recall: 0.9640 - auc: 0.9917 - f1_Score: 0.9634 - val_loss: 0.8068 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8315 - val_f1_Score: 0.7498 - lr: 3.1623e-09 - 17s/epoch - 674ms/step
# Epoch 65/75
# 25/25 - 17s - loss: 0.1067 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9920 - f1_Score: 0.9704 - val_loss: 0.9730 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.8082 - val_f1_Score: 0.7143 - lr: 3.1623e-09 - 17s/epoch - 678ms/step
# Epoch 66/75
# 25/25 - 17s - loss: 0.0969 - accuracy: 0.9717 - precision: 0.9717 - recall: 0.9717 - auc: 0.9936 - f1_Score: 0.9716 - val_loss: 0.8169 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8511 - val_f1_Score: 0.7881 - lr: 3.1623e-09 - 17s/epoch - 695ms/step
# Epoch 67/75
# 25/25 - 17s - loss: 0.0957 - accuracy: 0.9638 - precision: 0.9638 - recall: 0.9638 - auc: 0.9938 - f1_Score: 0.9636 - val_loss: 0.5346 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9094 - val_f1_Score: 0.8247 - lr: 3.1623e-09 - 17s/epoch - 686ms/step
# Epoch 68/75
# 25/25 - 17s - loss: 0.1153 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9918 - f1_Score: 0.9541 - val_loss: 0.6764 - val_accuracy: 0.7969 - val_precision: 0.7969 - val_recall: 0.7969 - val_auc: 0.8794 - val_f1_Score: 0.7928 - lr: 3.1623e-09 - 17s/epoch - 686ms/step
# Epoch 69/75
# 25/25 - 17s - loss: 0.0902 - accuracy: 0.9725 - precision: 0.9725 - recall: 0.9725 - auc: 0.9947 - f1_Score: 0.9722 - val_loss: 0.7715 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8325 - val_f1_Score: 0.8123 - lr: 1.0000e-09 - 17s/epoch - 699ms/step
# Epoch 70/75
# 25/25 - 17s - loss: 0.1278 - accuracy: 0.9538 - precision: 0.9538 - recall: 0.9538 - auc: 0.9893 - f1_Score: 0.9534 - val_loss: 0.7095 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8679 - val_f1_Score: 0.8000 - lr: 1.0000e-09 - 17s/epoch - 691ms/step
# Epoch 71/75
# 25/25 - 17s - loss: 0.0989 - accuracy: 0.9640 - precision: 0.9640 - recall: 0.9640 - auc: 0.9938 - f1_Score: 0.9639 - val_loss: 0.4937 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9231 - val_f1_Score: 0.8591 - lr: 1.0000e-09 - 17s/epoch - 670ms/step
# Epoch 72/75
# 25/25 - 17s - loss: 0.1141 - accuracy: 0.9614 - precision: 0.9614 - recall: 0.9614 - auc: 0.9911 - f1_Score: 0.9613 - val_loss: 0.6493 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.8623 - val_f1_Score: 0.8260 - lr: 1.0000e-09 - 17s/epoch - 671ms/step
# Epoch 73/75
# 25/25 - 17s - loss: 0.1105 - accuracy: 0.9614 - precision: 0.9614 - recall: 0.9614 - auc: 0.9912 - f1_Score: 0.9610 - val_loss: 0.8752 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8386 - val_f1_Score: 0.7804 - lr: 1.0000e-09 - 17s/epoch - 683ms/step
# Epoch 74/75
# 25/25 - 17s - loss: 0.0840 - accuracy: 0.9712 - precision: 0.9712 - recall: 0.9712 - auc: 0.9960 - f1_Score: 0.9711 - val_loss: 0.7944 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8350 - val_f1_Score: 0.7490 - lr: 3.1623e-10 - 17s/epoch - 691ms/step
# Epoch 75/75
# 25/25 - 17s - loss: 0.0857 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9958 - f1_Score: 0.9701 - val_loss: 0.9215 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8047 - val_f1_Score: 0.7520 - lr: 3.1623e-10 - 17s/epoch - 679ms/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']
learning_rate = history.history['lr']
print("Train Accuracy:" ,train_accuracy)
print("val Accuracy:" ,val_accuracy)
print("Train Loss:" ,train_loss)
print("val Loss:" ,val_loss)
# Out:
# Train Accuracy: [0.5037500262260437, 0.5037500262260437, 0.574999988079071, 0.5975000262260437, 0.6362500190734863, 0.6537500023841858, 0.6600000262260437, 0.6722365021705627, 0.7212499976158142, 0.7400000095367432, 0.7647814750671387, 0.8125, 0.8251928091049194, 0.8224999904632568, 0.8508997559547424, 0.8949999809265137, 0.8999999761581421, 0.918749988079071, 0.9125000238418579, 0.9300000071525574, 0.9362499713897705, 0.9375, 0.9449999928474426, 0.9462500214576721, 0.9537500143051147, 0.9487500190734863, 0.9474999904632568, 0.9640102982521057, 0.955012857913971, 0.9587500095367432, 0.9460154175758362, 0.9624999761581421, 0.9588689208030701, 0.9574999809265137, 0.9562981724739075, 0.9524421691894531, 0.9640102982521057, 0.9562981724739075, 0.9637500047683716, 0.9575835466384888, 0.9537274837493896, 0.9750000238418579, 0.9587500095367432, 0.9612500071525574, 0.9649999737739563, 0.9725000262260437, 0.9588689208030701, 0.9524421691894531, 0.9649999737739563, 0.9537500143051147, 0.9700000286102295, 0.9574999809265137, 0.9612500071525574, 0.9614396095275879, 0.9587500095367432, 0.9712499976158142, 0.9562981724739075, 0.9587500095367432, 0.956250011920929, 0.9725000262260437, 0.974293053150177, 0.9612500071525574, 0.9649999737739563, 0.9640102982521057, 0.9704369902610779, 0.9717223644256592, 0.9637500047683716, 0.9549999833106995, 0.9725000262260437, 0.9537500143051147, 0.9640102982521057, 0.9614396095275879, 0.9614396095275879, 0.9712499976158142, 0.9704369902610779]
# val Accuracy: [0.515625, 0.53125, 0.53125, 0.53125, 0.609375, 0.546875, 0.578125, 0.5625, 0.765625, 0.71875, 0.609375, 0.5625, 0.671875, 0.484375, 0.703125, 0.671875, 0.8125, 0.78125, 0.78125, 0.75, 0.765625, 0.734375, 0.84375, 0.71875, 0.703125, 0.8125, 0.703125, 0.890625, 0.796875, 0.78125, 0.703125, 0.8125, 0.796875, 0.796875, 0.75, 0.78125, 0.8125, 0.796875, 0.828125, 0.84375, 0.8125, 0.765625, 0.828125, 0.703125, 0.828125, 0.84375, 0.71875, 0.796875, 0.90625, 0.71875, 0.796875, 0.75, 0.84375, 0.765625, 0.8125, 0.828125, 0.671875, 0.8125, 0.84375, 0.75, 0.734375, 0.71875, 0.828125, 0.75, 0.71875, 0.796875, 0.828125, 0.796875, 0.8125, 0.8125, 0.859375, 0.828125, 0.78125, 0.75, 0.765625]
# Train Loss: [0.7363378405570984, 0.7097475528717041, 0.6888366937637329, 0.6661809682846069, 0.6771537065505981, 0.6422811150550842, 0.6240413784980774, 0.6163376569747925, 0.5551697015762329, 0.5406162142753601, 0.5213978290557861, 0.4300813674926758, 0.42912858724594116, 0.39005815982818604, 0.3625917434692383, 0.28193092346191406, 0.2541387677192688, 0.1959276646375656, 0.23463726043701172, 0.1978430300951004, 0.1778498888015747, 0.16207022964954376, 0.1463397741317749, 0.15508252382278442, 0.12172246724367142, 0.15080808103084564, 0.14782707393169403, 0.09735874086618423, 0.12852056324481964, 0.12118662148714066, 0.1349734365940094, 0.1035018190741539, 0.10512854903936386, 0.10559438914060593, 0.11565275490283966, 0.1275835931301117, 0.11806652694940567, 0.11773550510406494, 0.10625967383384705, 0.11796635389328003, 0.10301389545202255, 0.07746749371290207, 0.12356413155794144, 0.10835728794336319, 0.09304578602313995, 0.08708266168832779, 0.11414998769760132, 0.12044696509838104, 0.09899820387363434, 0.12868477404117584, 0.09282002598047256, 0.12864553928375244, 0.106987863779068, 0.10009120404720306, 0.10919176787137985, 0.0889778584241867, 0.10806576162576675, 0.10712045431137085, 0.11865510046482086, 0.08305051922798157, 0.09772691875696182, 0.12201844900846481, 0.09801727533340454, 0.11087282001972198, 0.1067260280251503, 0.09688015282154083, 0.09565401822328568, 0.11527875810861588, 0.09023979306221008, 0.1277758926153183, 0.09894641488790512, 0.11412517726421356, 0.1105339452624321, 0.08403801918029785, 0.08573233336210251]
# val Loss: [0.6900211572647095, 0.6604596376419067, 0.7048924565315247, 0.7285652160644531, 0.6703077554702759, 0.9689410328865051, 0.7468477487564087, 0.8055542707443237, 0.5456194877624512, 0.578129768371582, 0.6483209729194641, 1.4397614002227783, 0.7489904165267944, 2.180565357208252, 0.5796500444412231, 0.7376371622085571, 0.6054235696792603, 0.6651115417480469, 0.7541412115097046, 0.6221709251403809, 0.7417219877243042, 0.6841417551040649, 0.34138283133506775, 0.8509804010391235, 0.9565154910087585, 0.5807072520256042, 0.8715082406997681, 0.4221650958061218, 0.8457571864128113, 0.7319031953811646, 1.145749807357788, 0.7392355799674988, 0.6849836111068726, 0.5334693789482117, 0.7157236337661743, 0.7905594706535339, 0.6285117268562317, 0.747143030166626, 0.5479894876480103, 0.4979555010795593, 0.5030760765075684, 0.7967567443847656, 0.6296125650405884, 0.9675790071487427, 0.51835036277771, 0.7055580019950867, 1.0549252033233643, 0.5092625617980957, 0.34886932373046875, 0.807147741317749, 0.5048295259475708, 0.8547816872596741, 0.545642614364624, 0.6613520383834839, 0.7524300813674927, 0.633655309677124, 1.1947799921035767, 0.7627003192901611, 0.4264165461063385, 0.9533294439315796, 0.8377944827079773, 1.2817394733428955, 0.6183233261108398, 0.8067690134048462, 0.9729742407798767, 0.816921591758728, 0.5345803499221802, 0.6764266490936279, 0.7714856266975403, 0.7095078229904175, 0.49370837211608887, 0.6493101119995117, 0.8752362728118896, 0.794377326965332, 0.9214718341827393]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FakevsReal/FakevsReal/Validation'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 1116 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 35/35 [==============================] - 23s 607ms/step

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
print("done")
# Out:
# 83/83 [==============================] - 48s 576ms/step - loss: 0.0446 - accuracy: 0.9875 - precision: 0.9875 - recall: 0.9875 - auc: 0.9985 - f1_Score: 0.9873
# done

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.0445595309138298
# Train Accuracy: 0.9874715209007263
# Train Precision: 0.9874715209007263
# Train Recall: 0.9874715209007263
# Train AUC: 0.9984779357910156
# Train F1_Score: 0.9873414039611816

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 35/35 [==============================] - 13s 367ms/step - loss: 0.6956 - accuracy: 0.7921 - precision: 0.7921 - recall: 0.7921 - auc: 0.8660 - f1_Score: 0.7892

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.6956092119216919
# Test Accuracy: 0.7921146750450134
# Test Precision: 0.7921146750450134
# Test Recall: 0.7921146750450134
# Test AUC: 0.8659631609916687
# Test F1_Score: 0.7891650795936584

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#         fake       0.83      0.71      0.76       530
#         real       0.77      0.87      0.81       586
#
#     accuracy                           0.79      1116
#    macro avg       0.80      0.79      0.79      1116
# weighted avg       0.80      0.79      0.79      1116

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('EffectiveNetV2L.csv', index = False)
